# %% [markdown]
# <a href="https://colab.research.google.com/github/sneyx123-github/CopilotStudioSamples/blob/master/DrStop_v1_2_18_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dr Stop Section

# %% [markdown]
# HOW TO RUN CELLS
#
# 1.   In TOC: run Section "Dr Stop"
# 2.   In TOC: run Section "GRADIO PUSH PREP"
# 1.   In TOC: run Section "KORR1"
#
#
# 1.   In TERMINAL: "cd /content/drive/MyDrive/SadTalker_Patched_2026"
#
# 1.   In TERMINAL: cp ../requirements-fixed.txt requirements-fixed.txt
# 2.   In TERMINAL: cp ../Dockerfile Dockerfile
# 1.   In TERMINAL: cp ../app_sadtalker.py app_sadtalker.py
# 2.   In TERMINAL: bash -x ../z5.sh
# 2.   In TERMINAL: bash -x ../z5r.sh
#
#
#
#
#
#
#
#
# ---

# %%
from google.colab import drive
if 1:
  drive.mount("/content/drive", force_remount=True)
else:
  drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import clear_output
from datetime import datetime
from zoneinfo import ZoneInfo
from time import sleep

while 0:
  # clear_output clears the previous text,
  # then print adds the new line fresh
  clear_output(wait=True)

  if 1:
    # Define the target timezone (e.g., 'America/New_York' or 'UTC')
    tz = ZoneInfo("America/Los_Angeles")
    print(f"Current timezone: {tz.key}")


    # Get the current time in that timezone
    now_tz = datetime.now(tz)
    #print(f"{now_tz.strftime('%Y-%m-%d %H:%M:%S %Z')}")
    print(f"{now_tz.strftime('%Y-%m-%d %I:%M:%S %p %Z')}")


  sleep(1)

# %%
from IPython.display import clear_output
import time

for i in range(1, 6):
    # clear_output clears the previous text,
    # then print adds the new line fresh
    clear_output(wait=True)
    print(f"Processing... {i}/5")
    time.sleep(1)

print("Done!")
# Out:
# Processing... 5/5
# Done!

# %%
# %cd /content
# import os
# os.environ["COQUI_TOS_AGREED"] = "1"
# !pip install -q TTS==0.17.8

if 1:
  # !rm -rf /content/SadTalker/

if 1:
  # !rm -rf /content/drive/MyDrive/SadTalker_Patched_2026/

#BBI#!git clone -b v2.0 https://github.com/camenduru/SadTalker
# !git clone -b my2.0.1 https://github.com/sneyx123-github/SadTalker
# !pip install -q gradio safetensors kornia facexlib yacs gfpgan
# %cd /content/SadTalker

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/checkpoints/SadTalker_V0.0.2_256.safetensors -d /content/SadTalker/checkpoints -o SadTalker_V0.0.2_256.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/checkpoints/SadTalker_V0.0.2_512.safetensors -d /content/SadTalker/checkpoints -o SadTalker_V0.0.2_512.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/checkpoints/mapping_00109-model.pth.tar -d /content/SadTalker/checkpoints -o mapping_00109-model.pth.tar
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/checkpoints/mapping_00229-model.pth.tar -d /content/SadTalker/checkpoints -o mapping_00229-model.pth.tar
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/gfpgan/weights/GFPGANv1.4.pth -d /content/SadTalker/gfpgan/weights -o GFPGANv1.4.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/gfpgan/weights/alignment_WFLW_4HG.pth -d /content/SadTalker/gfpgan/weights -o alignment_WFLW_4HG.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/gfpgan/weights/detection_Resnet50_Final.pth -d /content/SadTalker/gfpgan/weights -o detection_Resnet50_Final.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/gfpgan/weights/parsing_parsenet.pth -d /content/SadTalker/gfpgan/weights -o parsing_parsenet.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/SadTalker/resolve/main/new/checkpoints/epoch_00190_iteration_000400000_checkpoint.pt -d /content/SadTalker/checkpoints -o epoch_00190_iteration_000400000_checkpoint.pt

#BBI#!python app_sadtalker.py
# Out:
# /content
# Cloning into 'SadTalker'...
# remote: Enumerating objects: 1665, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 1665 (delta 13), reused 21 (delta 7), pack-reused 1632 (from 1)
# Receiving objects: 100% (1665/1665), 92.29 MiB | 31.78 MiB/s, done.
# Resolving deltas: 100% (843/843), done.
# /content/SadTalker
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# abec20|OK  |    89MiB/s|/content/SadTalker/checkpoints/SadTalker_V0.0.2_256.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 589cad|OK  |   101MiB/s|/content/SadTalker/checkpoints/SadTalker_V0.0.2_512.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 722dae|OK  |   151MiB/s|/content/SadTalker/checkpoints/mapping_00109-model.pth.tar
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ad8911|OK  |   138MiB/s|/content/SadTalker/checkpoints/mapping_00229-model.pth.tar
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ed6d2e|OK  |   146MiB/s|/content/SadTalker/gfpgan/weights/GFPGANv1.4.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d5144f|OK  |   128MiB/s|/content/SadTalker/gfpgan/weights/alignment_WFLW_4HG.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 575931|OK  |   111MiB/s|/content/SadTalker/gfpgan/weights/detection_Resnet50_Final.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 715caa|OK  |    97MiB/s|/content/SadTalker/gfpgan/weights/parsing_parsenet.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8b3fe9|OK  |   144MiB/s|/content/SadTalker/checkpoints/epoch_00190_iteration_000400000_checkpoint.pt
#
# Status Legend:
# (OK):download completed.

# %%
# %cd /content/SadTalker
print("Installing engine parts...")
# !pip install kornia face-alignment facexlib resampy yacs gfpgan basicsr gradio
# Out:
# /content/SadTalker
# Installing engine parts...
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: face-alignment in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: facexlib in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: resampy in /usr/local/lib/python3.12/dist-packages (0.4.3)
# Requirement already satisfied: yacs in /usr/local/lib/python3.12/dist-packages (0.1.8)
# Requirement already satisfied: gfpgan in /usr/local/lib/python3.12/dist-packages (1.3.8)
# Requirement already satisfied: basicsr in /usr/local/lib/python3.12/dist-packages (1.4.2)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (26.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.10.0+cpu)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from face-alignment) (2.0.2)
# Requirement already satisfied: scipy>=0.17 in /usr/local/lib/python3.12/dist-packages (from face-alignment) (1.16.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from face-alignment) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from face-alignment) (4.13.0.92)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from face-alignment) (4.67.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from face-alignment) (0.60.0)
# Requirement already satisfied: filterpy in /usr/local/lib/python3.12/dist-packages (from facexlib) (1.4.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from facexlib) (11.3.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from facexlib) (0.25.0+cpu)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from yacs) (6.0.3)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.12/dist-packages (from gfpgan) (2.2.0)
# Requirement already satisfied: tb-nightly in /usr/local/lib/python3.12/dist-packages (from gfpgan) (2.21.0a20251023)
# Requirement already satisfied: yapf in /usr/local/lib/python3.12/dist-packages (from gfpgan) (0.43.0)
# Requirement already satisfied: addict in /usr/local/lib/python3.12/dist-packages (from basicsr) (2.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from basicsr) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from basicsr) (2.32.4)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.135.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.10.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.8)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pydantic<=2.12.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.26)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.15.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.44.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->face-alignment) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.6.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from filterpy->facexlib) (3.10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->basicsr) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->basicsr) (2.5.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->face-alignment) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->face-alignment) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->face-alignment) (0.5)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->gfpgan) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->gfpgan) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->gfpgan) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->gfpgan) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->gfpgan) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->gfpgan) (3.1.8)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->gfpgan) (4.9.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
# %cd /content/SadTalker

if 1:
  import os
  # Fix C: The Torchvision Functional_Tensor error in BasicSR
  basicsr_path = '/usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py'
  if os.path.exists(basicsr_path):
    with open(basicsr_path, 'r') as f:
        c = f.read().replace('functional_tensor', 'functional')
    with open(basicsr_path, 'w') as f:
        f.write(c)
    print("✅ System patched for 2026 compatibility.")
# Out:
# /content/SadTalker
# ✅ System patched for 2026 compatibility.

# %%
import numpy as np
import os
import sys

# 1. THE MONKEY PATCH: This fixes the Numpy crash for EVERY file at once
if not hasattr(np, "VisibleDeprecationWarning"):
    class VisibleDeprecationWarning(UserWarning): pass
    np.VisibleDeprecationWarning = VisibleDeprecationWarning
print("✅ Numpy Global Patch Applied.")

# 2. Add the current directory to the path so it finds 'src'
sys.path.append('/content/SadTalker')
os.environ['PYTHONPATH'] = '/content/SadTalker'
# Out:
# ✅ Numpy Global Patch Applied.

# %%
# 1. Install TTS and Audio processing libraries
print("Installing TTS and Audio engines...")
# !pip install TTS librosa

if 0:   # no effects
  # 2. Modernize the Image component one last time (Gradio 5.x fix)
  # Some versions of gr.Image no longer support 'type="filepath"' in the same way
  import os
  ui_file = '/content/SadTalker/app_sadtalker.py'
  if os.path.exists(ui_file):
    with open(ui_file, 'r') as f:
        content = f.read()
    # If the previous fix missed any 'source' arguments, we clear them here
    content = content.replace('source="upload"', '').replace("source='upload'", "")
    with open(ui_file, 'w') as f:
        f.write(content)
# Out:
# Installing TTS and Audio engines...
# ERROR: Ignored the following versions that require a different python version: 0.0.10.2 Requires-Python >=3.6.0, <3.9; 0.0.10.3 Requires-Python >=3.6.0, <3.9; 0.0.11 Requires-Python >=3.6.0, <3.9; 0.0.12 Requires-Python >=3.6.0, <3.9; 0.0.13.1 Requires-Python >=3.6.0, <3.9; 0.0.13.2 Requires-Python >=3.6.0, <3.9; 0.0.14.1 Requires-Python >=3.6.0, <3.9; 0.0.15 Requires-Python >=3.6.0, <3.9; 0.0.15.1 Requires-Python >=3.6.0, <3.9; 0.0.9 Requires-Python >=3.6.0, <3.9; 0.0.9.1 Requires-Python >=3.6.0, <3.9; 0.0.9.2 Requires-Python >=3.6.0, <3.9; 0.0.9a10 Requires-Python >=3.6.0, <3.9; 0.0.9a9 Requires-Python >=3.6.0, <3.9; 0.1.0 Requires-Python >=3.6.0, <3.10; 0.1.1 Requires-Python >=3.6.0, <3.10; 0.1.2 Requires-Python >=3.6.0, <3.10; 0.1.3 Requires-Python >=3.6.0, <3.10; 0.10.0 Requires-Python >=3.7.0, <3.11; 0.10.1 Requires-Python >=3.7.0, <3.11; 0.10.2 Requires-Python >=3.7.0, <3.11; 0.11.0 Requires-Python >=3.7.0, <3.11; 0.11.1 Requires-Python >=3.7.0, <3.11; 0.12.0 Requires-Python >=3.7.0, <3.11; 0.13.0 Requires-Python >=3.7.0, <3.11; 0.13.1 Requires-Python >=3.7.0, <3.11; 0.13.2 Requires-Python >=3.7.0, <3.11; 0.13.3 Requires-Python >=3.7.0, <3.11; 0.14.0 Requires-Python >=3.7.0, <3.11; 0.14.2 Requires-Python >=3.7.0, <3.11; 0.14.3 Requires-Python >=3.7.0, <3.11; 0.15.0 Requires-Python >=3.9.0, <3.12; 0.15.1 Requires-Python >=3.9.0, <3.12; 0.15.2 Requires-Python >=3.9.0, <3.12; 0.15.4 Requires-Python >=3.9.0, <3.12; 0.15.5 Requires-Python >=3.9.0, <3.12; 0.15.6 Requires-Python >=3.9.0, <3.12; 0.16.0 Requires-Python >=3.9.0, <3.12; 0.16.1 Requires-Python >=3.9.0, <3.12; 0.16.3 Requires-Python >=3.9.0, <3.12; 0.16.4 Requires-Python >=3.9.0, <3.12; 0.16.5 Requires-Python >=3.9.0, <3.12; 0.16.6 Requires-Python >=3.9.0, <3.12; 0.17.0 Requires-Python >=3.9.0, <3.12; 0.17.1 Requires-Python >=3.9.0, <3.12; 0.17.2 Requires-Python >=3.9.0, <3.12; 0.17.4 Requires-Python >=3.9.0, <3.12; 0.17.5 Requires-Python >=3.9.0, <3.12; 0.17.6 Requires-Python >=3.9.0, <3.12; 0.17.7 Requires-Python >=3.9.0, <3.12; 0.17.8 Requires-Python >=3.9.0, <3.12; 0.17.9 Requires-Python >=3.9.0, <3.12; 0.18.0 Requires-Python >=3.9.0, <3.12; 0.18.1 Requires-Python >=3.9.0, <3.12; 0.18.2 Requires-Python >=3.9.0, <3.12; 0.19.0 Requires-Python >=3.9.0, <3.12; 0.19.1 Requires-Python >=3.9.0, <3.12; 0.2.0 Requires-Python >=3.6.0, <3.10; 0.2.1 Requires-Python >=3.6.0, <3.10; 0.2.2 Requires-Python >=3.6.0, <3.10; 0.20.0 Requires-Python >=3.9.0, <3.12; 0.20.1 Requires-Python >=3.9.0, <3.12; 0.20.2 Requires-Python >=3.9.0, <3.12; 0.20.3 Requires-Python >=3.9.0, <3.12; 0.20.4 Requires-Python >=3.9.0, <3.12; 0.20.5 Requires-Python >=3.9.0, <3.12; 0.20.6 Requires-Python >=3.9.0, <3.12; 0.21.0 Requires-Python >=3.9.0, <3.12; 0.21.1 Requires-Python >=3.9.0, <3.12; 0.21.2 Requires-Python >=3.9.0, <3.12; 0.21.3 Requires-Python >=3.9.0, <3.12; 0.22.0 Requires-Python >=3.9.0, <3.12; 0.3.0 Requires-Python >=3.6.0, <3.10; 0.3.1 Requires-Python >=3.6.0, <3.10; 0.4.0 Requires-Python >=3.6.0, <3.10; 0.4.1 Requires-Python >=3.6.0, <3.10; 0.4.2 Requires-Python >=3.6.0, <3.10; 0.5.0 Requires-Python >=3.6.0, <3.10; 0.6.0 Requires-Python >=3.6.0, <3.10; 0.6.1 Requires-Python >=3.6.0, <3.10; 0.6.2 Requires-Python >=3.6.0, <3.10; 0.7.0 Requires-Python >=3.7.0, <3.11; 0.7.1 Requires-Python >=3.7.0, <3.11; 0.8.0 Requires-Python >=3.7.0, <3.11; 0.9.0 Requires-Python >=3.7.0, <3.11
# ERROR: Could not find a version that satisfies the requirement TTS (from versions: none)
# ERROR: No matching distribution found for TTS

# %% [markdown]
# ASSUME GDRIVE MOUNTED HERE
#
# ---

# %%
# 1. Step out of the folder to the main area
# %cd /content/

# 2. Force the copy (The -u flag only copies new/changed files)
print("Moving the patched Dr. Stop engine to your permanent Drive storage...")
# !cp -rn /content/SadTalker /content/drive/MyDrive/SadTalker_Patched_2026
# Out:
# /content
# Moving the patched Dr. Stop engine to your permanent Drive storage...

# %%
# 1. Ensure we are in the patched folder
# %cd /content/drive/MyDrive/SadTalker_Patched_2026/

# 2. Launch the UI (No installs needed if the session is still active)
#BBI#!export PYTHONPATH=$PYTHONPATH:/content/drive/MyDrive/SadTalker_Patched_2026 && python app_sadtalker.py --share
# Out:
# /content/drive/MyDrive/SadTalker_Patched_2026

# %%
import os

# Path to the file in your Drive
drive_ui_file = '/content/drive/MyDrive/SadTalker_Patched_2026/app_sadtalker.py'

if os.path.exists(drive_ui_file):
    with open(drive_ui_file, 'r') as f:
        content = f.read()

    # Remove the problematic 'type="filepath"' from the Video component
    content = content.replace('type="filepath", elem_id="vidref"', 'elem_id="vidref"')
    content = content.replace("type='filepath', elem_id='vidref'", "elem_id='vidref'")

    with open(drive_ui_file, 'w') as f:
        f.write(content)
    print("✅ Drive UI Updated: 'type' argument removed from Video component.")
else:
    print("❌ Error: Could not find the file in your Drive. Make sure it is mounted!")

# Final Launch Attempt
#print("\n--- Relaunching Dr. Stop (Final Patch) ---")
#%cd /content/drive/MyDrive/SadTalker_Patched_2026/
#BBI#!export PYTHONPATH=$PYTHONPATH:/content/drive/MyDrive/SadTalker_Patched_2026 && python app_sadtalker.py --share
# Out:
# ✅ Drive UI Updated: 'type' argument removed from Video component.

# %%
import os
import fileinput

# The specific file in the library causing the crash
target_lib_file = '/usr/local/lib/python3.12/dist-packages/facexlib/alignment/awing_arch.py'

if os.path.exists(target_lib_file):
    with open(target_lib_file, 'r') as f:
        content = f.read()

    # Apply the fix: change np.float to just float
    fixed_content = content.replace('astype(np.float', 'astype(float')

    with open(target_lib_file, 'w') as f:
        f.write(fixed_content)
    print("✅ System Library Patched: facexlib is now compatible with 2026 Numpy.")
else:
    print("❌ Could not find the library file. Ensure you ran the pip installs first!")
# Out:
# ✅ System Library Patched: facexlib is now compatible with 2026 Numpy.

# %%
import os

ui_file = '/content/drive/MyDrive/SadTalker_Patched_2026/app_sadtalker.py'

if os.path.exists(ui_file):
    with open(ui_file, 'r') as f:
        lines = f.readlines()

    fixed_lines = []
    for line in lines:
        # 1. Remove .style(...) calls which cause the AttributeError
        # We use a split to catch variations like .style(width=512) or .style(height=256)
        if '.style(' in line:
            line = line.split('.style(')[0] + '\n'

        # 2. Fix the Image source argument (Gradio 5 handles this automatically)
        line = line.replace('source="upload",', '')

        fixed_lines.append(line)

    with open(ui_file, 'w') as f:
        f.writelines(fixed_lines)
    print("✅ Drive UI Purged: All .style() calls and legacy Image arguments removed.")
else:
    print("❌ UI file not found in Drive. Check your mount!")

# Final Launch Attempt
#print("\n--- Starting Dr. Stop Engine (Full UI Modernization) ---")
#%cd /content/drive/MyDrive/SadTalker_Patched_2026/
#BBI#!export PYTHONPATH=$PYTHONPATH:/content/drive/MyDrive/SadTalker_Patched_2026 && python app_sadtalker.py --share
# Out:
# ✅ Drive UI Purged: All .style() calls and legacy Image arguments removed.

# %%
import os

target_file = '/content/drive/MyDrive/SadTalker_Patched_2026/src/face3d/util/preprocess.py'

if os.path.exists(target_file):
    with open(target_file, 'r') as f:
        content = f.read()

    # The fix: We ensure t[0] and t[1] are extracted as scalars, not sequences
    old_line = 'trans_params = np.array([w0, h0, s, t[0], t[1]])'
    new_line = 'trans_params = np.array([float(w0), float(h0), float(s), float(t[0]), float(t[1])])'

    if old_line in content:
        content = content.replace(old_line, new_line)
        with open(target_file, 'w') as f:
            f.write(content)
        print("✅ 3D Alignment Math Patched. Inhomogeneous shape error averted.")
    else:
        print("⚠️ Could not find the exact line, it might already be patched or slightly different.")
else:
    print("❌ File not found in Drive.")

# No need to restart the whole notebook, just the launch cell!
# Out:
# ✅ 3D Alignment Math Patched. Inhomogeneous shape error averted.

# %%
import os
import re

target_file = '/content/drive/MyDrive/SadTalker_Patched_2026/src/face3d/util/preprocess.py'

if os.path.exists(target_file):
    with open(target_file, 'r') as f:
        content = f.read()

    # We look for the pattern np.array([..., t[0], t[1]]) regardless of spacing
    pattern = r'np\.array\(\s*\[\s*w0\s*,\s*h0\s*,\s*s\s*,\s*t\[0\]\s*,\s*t\[1\]\s*\]\s*\)'
    new_code = 'np.array([float(w0), float(h0), float(s), float(t[0]), float(t[1])])'

    if re.search(pattern, content):
        content = re.sub(pattern, new_code, content)
        with open(target_file, 'w') as f:
            f.write(content)
        print("✅ SUCCESS: 3D Math Alignment fixed with Regex.")
    else:
        # If it's still not found, let's just force the line near the known context
        if 'trans_params =' in content:
             content = re.sub(r'trans_params =.*', f'trans_params = {new_code}', content)
             with open(target_file, 'w') as f:
                f.write(content)
             print("✅ FORCED SUCCESS: Overwrote the trans_params line directly.")
        else:
             print("❌ CRITICAL: Could not find 'trans_params' in the file.")
else:
    print("❌ DRIVE ERROR: File not found. Is your Drive still mounted?")
# Out:
# ✅ FORCED SUCCESS: Overwrote the trans_params line directly.

# %%
import os

demo_file = '/content/drive/MyDrive/SadTalker_Patched_2026/src/gradio_demo.py'

if os.path.exists(demo_file):
    with open(demo_file, 'r') as f:
        content = f.read()

    # We change the return path so Gradio doesn't try to edit the file in-place
    # We'll append '_final' to the result name
    old_code = "return return_path"
    new_code = """
    import shutil
    final_output = return_path.replace('.mp4', '_ready.mp4')
    shutil.copy(return_path, final_output)
    return final_output
    """

    if old_code in content:
        content = content.replace(old_code, new_code)
        with open(demo_file, 'w') as f:
            f.write(content)
        print("✅ Gradio Output Logic Patched: No more FFmpeg in-place errors.")
    else:
        print("⚠️ Patch target not found. It may have been modified already.")
else:
    print("❌ File not found. Check your Drive path!")
# Out:
# ✅ Gradio Output Logic Patched: No more FFmpeg in-place errors.

# %%
import os

demo_file = '/content/drive/MyDrive/SadTalker_Patched_2026/src/gradio_demo.py'

if os.path.exists(demo_file):
    with open(demo_file, 'r') as f:
        lines = f.readlines()

    new_lines = []
    skip_mode = False

    for line in lines:
        # If we hit the broken return, we replace it with the properly indented block
        if 'return return_path' in line or 'return final_output' in line:
            # We use 8 spaces because 'test' is a method inside the 'SadTalker' class
            new_lines.append("        import shutil\n")
            new_lines.append("        final_output = return_path.replace('.mp4', '_ready.mp4')\n")
            new_lines.append("        shutil.copy(return_path, final_output)\n")
            new_lines.append("        return final_output\n")
        else:
            new_lines.append(line)

    with open(demo_file, 'w') as f:
        f.writelines(new_lines)
    print("✅ Syntax Fixed: 'return' is now safely back inside the function.")
else:
    print("❌ File not found. Verify your Drive mount.")
# Out:
# ✅ Syntax Fixed: 'return' is now safely back inside the function.

# %%
import os

demo_file = '/content/drive/MyDrive/SadTalker_Patched_2026/src/gradio_demo.py'

if os.path.exists(demo_file):
    with open(demo_file, 'r') as f:
        lines = f.readlines()

    fixed_lines = []
    for line in lines:
        # We look for the lines we inserted and force them to 8 spaces
        # (This is the standard depth for a method inside a class in this repo)
        if any(x in line for x in ['import shutil', 'final_output =', 'shutil.copy', 'return final_output']):
            indent = "        " # Exactly 8 spaces
            content = line.strip()
            fixed_lines.append(f"{indent}{content}\n")
        else:
            fixed_lines.append(line)

    with open(demo_file, 'w') as f:
        f.writelines(fixed_lines)
    print("✅ Indentation Hard-Aligned: 8-space standard applied.")
else:
    print("❌ File not found. Verify Drive mount.")
# Out:
# ✅ Indentation Hard-Aligned: 8-space standard applied.

# %%
import os

demo_file = '/content/drive/MyDrive/SadTalker_Patched_2026/src/gradio_demo.py'

if os.path.exists(demo_file):
    with open(demo_file, 'r') as f:
        content = f.read()

    # 1. Add shutil to the top if it's not there
    if "import shutil" not in content[:100]:
        content = "import shutil\n" + content

    # 2. Clean up the messy indentation from the previous attempt at the bottom
    # We'll make sure the return block is clean and uses the global shutil
    lines = content.splitlines()
    final_lines = []
    for line in lines:
        if 'import shutil' in line and '        ' in line: # Remove the nested one
            continue
        final_lines.append(line)

    with open(demo_file, 'w') as f:
        f.write("\n".join(final_lines))

    print("✅ Shutil promoted to Global Scope. Logic cleaned.")
else:
    print("❌ File not found.")
# Out:
# ✅ Shutil promoted to Global Scope. Logic cleaned.

# %%
import os

demo_file = '/content/drive/MyDrive/SadTalker_Patched_2026/src/gradio_demo.py'

if os.path.exists(demo_file):
    with open(demo_file, 'r') as f:
        content = f.read()

    # We create a specific 'display' version in a different folder
    # so Gradio doesn't try to overwrite the source file in 'results'
    old_logic = "return final_output"
    new_logic = """
        web_display_path = os.path.join('/content', 'gradio_display_output.mp4')
        shutil.copy(final_output, web_display_path)
        return web_display_path
    """

    if old_logic in content:
        content = content.replace(old_logic, new_logic)
        with open(demo_file, 'w') as f:
            f.write(content)
        print("✅ Gradio Display Redirected. The UI should now stay stable.")
    else:
        print("⚠️ Patch target not found. Check if logic was already updated.")
# Out:
# ✅ Gradio Display Redirected. The UI should now stay stable.

# %%
import os
import shutil

demo_file = '/content/drive/MyDrive/SadTalker_Patched_2026/src/gradio_demo.py'

def apply_final_patch():
    if not os.path.exists(demo_file):
        print("❌ File not found. Check Drive mount.")
        return

    with open(demo_file, 'r') as f:
        content = f.read()

    # The most reliable way to find the return line
    # We look for the shutil.copy line we added earlier and update it
    if "return final_output" in content:
        new_logic = """        web_display_path = os.path.join('/content', 'gradio_display_output.mp4')
        if os.path.exists(final_output):
            import shutil
            shutil.copy(final_output, web_display_path)
        return web_display_path"""

        updated_content = content.replace("        return final_output", new_logic)

        with open(demo_file, 'w') as f:
            f.write(updated_content)
        print("✅ SUCCESS: Gradio UI display redirected to /content.")
    elif "web_display_path" in content:
        print("ℹ️ File already patched.")
    else:
        print("⚠️ Could not find the return line. Manual check required.")

apply_final_patch()
# Out:
# ℹ️ File already patched.

# %%
import os

app_file = '/content/drive/MyDrive/SadTalker_Patched_2026/app_sadtalker.py'

if os.path.exists(app_file):
    with open(app_file, 'r') as f:
        content = f.read()

    # We add allowed_paths=["/content"] to the launch command
    if '.launch(' in content and 'allowed_paths' not in content:
        content = content.replace('.launch(', '.launch(allowed_paths=["/content"], ')
        with open(app_file, 'w') as f:
            f.write(content)
        print("✅ Gradio Launch Security updated: /content is now allowed.")
    else:
        print("ℹ️ Launch command already updated or not found.")
# Out:
# ✅ Gradio Launch Security updated: /content is now allowed.

# %%
# 1. Enter the patched directory
# %cd /content/drive/MyDrive/SadTalker_Patched_2026/

# 2. Launch
if 0:
  # !export PYTHONPATH=$PYTHONPATH:/content/drive/MyDrive/SadTalker_Patched_2026 && python app_sadtalker.py --share
# Out:
# /content/drive/MyDrive/SadTalker_Patched_2026

# %% [markdown]
# # GRADIO PUSH PREP Section

# %% [markdown]
# The code is located in a Google Colab cell.
# Can you guide me through deploying this specific code to Google Cloud Run?
#
# The Google Cloud project is project-46810a95-b6e5-47e4-adb.
#
# ---
#
#
# https://share.google/aimode/tNjIcudjj1rYWRxd0

# %%
from google.colab import auth
PROJECT_ID = "project-46810a95-b6e5-47e4-adb"

# Melde dich mit deinem Google-Konto an
auth.authenticate_user()

# Setze das Projekt für die gcloud CLI
# !gcloud config set project {PROJECT_ID}
# Out:
# [environment: untagged] Read more to tag: g.co/cloud/project-env-tag.
# Updated property [core/project].
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey

# %%
# !gcloud services enable run.googleapis.com cloudbuild.googleapis.com artifactregistry.googleapis.com
# Out:
# Operation "operations/acat.p2-1074528386995-d46fce0f-a0cc-42bc-8b13-45605b48f953" finished successfully.

# %% [markdown]
# # KORR1 Section

# %% [markdown]
# KORR1
#
#
# ---

# %%
# Projektnummer abfragen
PROJECT_NUMBER = !gcloud projects describe {PROJECT_ID} --format='value(projectNumber)'
PROJECT_NUMBER = PROJECT_NUMBER[0]
print(f"Deine Projektnummer ist: {PROJECT_NUMBER}")
# Out:
# Deine Projektnummer ist: 1074528386995

# %%
BUILD_SA = f"{PROJECT_NUMBER}@cloudbuild.gserviceaccount.com"

# 1. Cloud Run Admin (um den Service zu erstellen/aktualisieren)
# !gcloud projects add-iam-policy-binding {PROJECT_ID} \
    --member=serviceAccount:{BUILD_SA} \
    --role=roles/run.admin

# 2. Service Account User (um das Laufzeit-Service-Konto zu verwenden)
# !gcloud projects add-iam-policy-binding {PROJECT_ID} \
    --member=serviceAccount:{BUILD_SA} \
    --role=roles/iam.serviceAccountUser

# 3. Storage Object Admin (um auf den Quellcode-Bucket zuzugreifen)
# !gcloud projects add-iam-policy-binding {PROJECT_ID} \
    --member=serviceAccount:{BUILD_SA} \
    --role=roles/storage.objectAdmin
# Out:
# Updated IAM policy for project [project-46810a95-b6e5-47e4-adb].
# bindings:
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-artifactregistry.iam.gserviceaccount.com
#   role: roles/artifactregistry.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/artifactregistry.writer
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudaicompanion.iam.gserviceaccount.com
#   role: roles/cloudaicompanion.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/cloudbuild.builds.builder
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudbuild.iam.gserviceaccount.com
#   role: roles/cloudbuild.serviceAgent
# - members:
#   - serviceAccount:service-1074528386995@containerregistry.iam.gserviceaccount.com
#   role: roles/containerregistry.ServiceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/iam.serviceAccountUser
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/logging.logWriter
# - members:
#   - user:simonborisney@gmail.com
#   role: roles/owner
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-pubsub.iam.gserviceaccount.com
#   role: roles/pubsub.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/run.admin
# - members:
#   - serviceAccount:service-1074528386995@serverless-robot-prod.iam.gserviceaccount.com
#   role: roles/run.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/secretmanager.secretAccessor
# - members:
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/storage.objectAdmin
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/storage.objectViewer
# etag: BwZPqgtpECU=
# version: 1
# Updated IAM policy for project [project-46810a95-b6e5-47e4-adb].
# bindings:
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-artifactregistry.iam.gserviceaccount.com
#   role: roles/artifactregistry.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/artifactregistry.writer
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudaicompanion.iam.gserviceaccount.com
#   role: roles/cloudaicompanion.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/cloudbuild.builds.builder
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudbuild.iam.gserviceaccount.com
#   role: roles/cloudbuild.serviceAgent
# - members:
#   - serviceAccount:service-1074528386995@containerregistry.iam.gserviceaccount.com
#   role: roles/containerregistry.ServiceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/iam.serviceAccountUser
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/logging.logWriter
# - members:
#   - user:simonborisney@gmail.com
#   role: roles/owner
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-pubsub.iam.gserviceaccount.com
#   role: roles/pubsub.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/run.admin
# - members:
#   - serviceAccount:service-1074528386995@serverless-robot-prod.iam.gserviceaccount.com
#   role: roles/run.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/secretmanager.secretAccessor
# - members:
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/storage.objectAdmin
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/storage.objectViewer
# etag: BwZPqguN-JY=
# version: 1
# Updated IAM policy for project [project-46810a95-b6e5-47e4-adb].
# bindings:
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-artifactregistry.iam.gserviceaccount.com
#   role: roles/artifactregistry.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/artifactregistry.writer
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudaicompanion.iam.gserviceaccount.com
#   role: roles/cloudaicompanion.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/cloudbuild.builds.builder
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudbuild.iam.gserviceaccount.com
#   role: roles/cloudbuild.serviceAgent
# - members:
#   - serviceAccount:service-1074528386995@containerregistry.iam.gserviceaccount.com
#   role: roles/containerregistry.ServiceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/iam.serviceAccountUser
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/logging.logWriter
# - members:
#   - user:simonborisney@gmail.com
#   role: roles/owner
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-pubsub.iam.gserviceaccount.com
#   role: roles/pubsub.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/run.admin
# - members:
#   - serviceAccount:service-1074528386995@serverless-robot-prod.iam.gserviceaccount.com
#   role: roles/run.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/secretmanager.secretAccessor
# - members:
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/storage.objectAdmin
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/storage.objectViewer
# etag: BwZPqgu0S40=
# version: 1

# %% [markdown]
# KORR2
#
#
# ---

# %%
COMPUTE_SA = "1074528386995-compute@developer.gserviceaccount.com"

# Erlaubnis zum Lesen der Quellcode-Dateien im Storage geben
# !gcloud projects add-iam-policy-binding project-46810a95-b6e5-47e4-adb \
    --member=serviceAccount:{COMPUTE_SA} \
    --role=roles/storage.objectViewer

# Zusätzlich Sicherheitshalber Cloud Build Rechte geben
# !gcloud projects add-iam-policy-binding project-46810a95-b6e5-47e4-adb \
    --member=serviceAccount:{COMPUTE_SA} \
    --role=roles/cloudbuild.builds.builder
# Out:
# Updated IAM policy for project [project-46810a95-b6e5-47e4-adb].
# bindings:
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-artifactregistry.iam.gserviceaccount.com
#   role: roles/artifactregistry.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/artifactregistry.writer
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudaicompanion.iam.gserviceaccount.com
#   role: roles/cloudaicompanion.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/cloudbuild.builds.builder
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudbuild.iam.gserviceaccount.com
#   role: roles/cloudbuild.serviceAgent
# - members:
#   - serviceAccount:service-1074528386995@containerregistry.iam.gserviceaccount.com
#   role: roles/containerregistry.ServiceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/iam.serviceAccountUser
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/logging.logWriter
# - members:
#   - user:simonborisney@gmail.com
#   role: roles/owner
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-pubsub.iam.gserviceaccount.com
#   role: roles/pubsub.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/run.admin
# - members:
#   - serviceAccount:service-1074528386995@serverless-robot-prod.iam.gserviceaccount.com
#   role: roles/run.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/secretmanager.secretAccessor
# - members:
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/storage.objectAdmin
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/storage.objectViewer
# etag: BwZPqgvWDzU=
# version: 1
# Updated IAM policy for project [project-46810a95-b6e5-47e4-adb].
# bindings:
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-artifactregistry.iam.gserviceaccount.com
#   role: roles/artifactregistry.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/artifactregistry.writer
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudaicompanion.iam.gserviceaccount.com
#   role: roles/cloudaicompanion.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/cloudbuild.builds.builder
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-cloudbuild.iam.gserviceaccount.com
#   role: roles/cloudbuild.serviceAgent
# - members:
#   - serviceAccount:service-1074528386995@containerregistry.iam.gserviceaccount.com
#   role: roles/containerregistry.ServiceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/iam.serviceAccountUser
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/logging.logWriter
# - members:
#   - user:simonborisney@gmail.com
#   role: roles/owner
# - members:
#   - serviceAccount:service-1074528386995@gcp-sa-pubsub.iam.gserviceaccount.com
#   role: roles/pubsub.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/run.admin
# - members:
#   - serviceAccount:service-1074528386995@serverless-robot-prod.iam.gserviceaccount.com
#   role: roles/run.serviceAgent
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/secretmanager.secretAccessor
# - members:
#   - serviceAccount:1074528386995@cloudbuild.gserviceaccount.com
#   role: roles/storage.objectAdmin
# - members:
#   - serviceAccount:1074528386995-compute@developer.gserviceaccount.com
#   role: roles/storage.objectViewer
# etag: BwZPqgv2JGc=
# version: 1

# %% [markdown]
# # CLOUD BUILD Section

# %%
# %cd /content/drive/MyDrive/SadTalker_Patched_2026/
# !cp ../Dockerfile-NEW5 Dockerfile
# !diff ../app_sadtalker-COLAB-GIT.py app_sadtalker.py
# !cp ../requirements-fixed-NEW.txt requirements-fixed.txt
# !bash -x ../z5-build.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#
# /install/lib/python3.10/site-packages/torch/mtia/__pycache__:
# __init__.cpython-310.pyc
# _utils.cpython-310.pyc
# memory.cpython-310.pyc
# mtia_graph.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/multiprocessing:
# __init__.py
# __pycache__
# _atfork.py
# pool.py
# queue.py
# reductions.py
# spawn.py
#
# /install/lib/python3.10/site-packages/torch/multiprocessing/__pycache__:
# __init__.cpython-310.pyc
# _atfork.cpython-310.pyc
# pool.cpython-310.pyc
# queue.cpython-310.pyc
# reductions.cpython-310.pyc
# spawn.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nativert:
# __init__.py
# __pycache__
# backends
#
# /install/lib/python3.10/site-packages/torch/nativert/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nativert/backends:
# __init__.py
# __pycache__
# _lower_utils.py
# _lowered_aoti_module.py
#
# /install/lib/python3.10/site-packages/torch/nativert/backends/__pycache__:
# __init__.cpython-310.pyc
# _lower_utils.cpython-310.pyc
# _lowered_aoti_module.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nested:
# __init__.py
# __pycache__
# _internal
#
# /install/lib/python3.10/site-packages/torch/nested/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nested/_internal:
# __init__.py
# __pycache__
# nested_int.py
# nested_tensor.py
# ops.py
# sdpa.py
#
# /install/lib/python3.10/site-packages/torch/nested/_internal/__pycache__:
# __init__.cpython-310.pyc
# nested_int.cpython-310.pyc
# nested_tensor.cpython-310.pyc
# ops.cpython-310.pyc
# sdpa.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn:
# __init__.py
# __pycache__
# _reduction.py
# attention
# backends
# common_types.py
# cpp.py
# functional.py
# functional.pyi
# grad.py
# init.py
# intrinsic
# modules
# parallel
# parameter.py
# parameter.pyi
# qat
# quantizable
# quantized
# utils
#
# /install/lib/python3.10/site-packages/torch/nn/__pycache__:
# __init__.cpython-310.pyc
# _reduction.cpython-310.pyc
# common_types.cpython-310.pyc
# cpp.cpython-310.pyc
# functional.cpython-310.pyc
# grad.cpython-310.pyc
# init.cpython-310.pyc
# parameter.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/attention:
# __init__.py
# __pycache__
# _fa3.py
# _fa4.py
# _registry.py
# _utils.py
# bias.py
# experimental
# flex_attention.py
# varlen.py
#
# /install/lib/python3.10/site-packages/torch/nn/attention/__pycache__:
# __init__.cpython-310.pyc
# _fa3.cpython-310.pyc
# _fa4.cpython-310.pyc
# _registry.cpython-310.pyc
# _utils.cpython-310.pyc
# bias.cpython-310.pyc
# flex_attention.cpython-310.pyc
# varlen.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/attention/experimental:
# __init__.py
# __pycache__
# _paged_attention.py
# _scaled_dot_product_attention_quantized.py
#
# /install/lib/python3.10/site-packages/torch/nn/attention/experimental/__pycache__:
# __init__.cpython-310.pyc
# _paged_attention.cpython-310.pyc
# _scaled_dot_product_attention_quantized.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/backends:
# __init__.py
# __pycache__
# thnn.py
#
# /install/lib/python3.10/site-packages/torch/nn/backends/__pycache__:
# __init__.cpython-310.pyc
# thnn.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic:
# __init__.py
# __pycache__
# modules
# qat
# quantized
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/modules:
# __init__.py
# __pycache__
# fused.py
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/modules/__pycache__:
# __init__.cpython-310.pyc
# fused.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/qat:
# __init__.py
# __pycache__
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/qat/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/qat/modules:
# __init__.py
# __pycache__
# conv_fused.py
# linear_fused.py
# linear_relu.py
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/qat/modules/__pycache__:
# __init__.cpython-310.pyc
# conv_fused.cpython-310.pyc
# linear_fused.cpython-310.pyc
# linear_relu.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/quantized:
# __init__.py
# __pycache__
# dynamic
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/quantized/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/quantized/dynamic:
# __init__.py
# __pycache__
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/quantized/dynamic/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/quantized/dynamic/modules:
# __init__.py
# __pycache__
# linear_relu.py
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/quantized/dynamic/modules/__pycache__:
# __init__.cpython-310.pyc
# linear_relu.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/quantized/modules:
# __init__.py
# __pycache__
# bn_relu.py
# conv_relu.py
# linear_relu.py
#
# /install/lib/python3.10/site-packages/torch/nn/intrinsic/quantized/modules/__pycache__:
# __init__.cpython-310.pyc
# bn_relu.cpython-310.pyc
# conv_relu.cpython-310.pyc
# linear_relu.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/modules:
# __init__.py
# __pycache__
# _functions.py
# activation.py
# adaptive.py
# batchnorm.py
# channelshuffle.py
# container.py
# conv.py
# distance.py
# dropout.py
# flatten.py
# fold.py
# instancenorm.py
# lazy.py
# linear.py
# loss.py
# module.py
# normalization.py
# padding.py
# pixelshuffle.py
# pooling.py
# rnn.py
# sparse.py
# transformer.py
# upsampling.py
# utils.py
#
# /install/lib/python3.10/site-packages/torch/nn/modules/__pycache__:
# __init__.cpython-310.pyc
# _functions.cpython-310.pyc
# activation.cpython-310.pyc
# adaptive.cpython-310.pyc
# batchnorm.cpython-310.pyc
# channelshuffle.cpython-310.pyc
# container.cpython-310.pyc
# conv.cpython-310.pyc
# distance.cpython-310.pyc
# dropout.cpython-310.pyc
# flatten.cpython-310.pyc
# fold.cpython-310.pyc
# instancenorm.cpython-310.pyc
# lazy.cpython-310.pyc
# linear.cpython-310.pyc
# loss.cpython-310.pyc
# module.cpython-310.pyc
# normalization.cpython-310.pyc
# padding.cpython-310.pyc
# pixelshuffle.cpython-310.pyc
# pooling.cpython-310.pyc
# rnn.cpython-310.pyc
# sparse.cpython-310.pyc
# transformer.cpython-310.pyc
# upsampling.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/parallel:
# __init__.py
# __pycache__
# _functions.py
# comm.py
# data_parallel.py
# distributed.py
# parallel_apply.py
# replicate.py
# scatter_gather.py
#
# /install/lib/python3.10/site-packages/torch/nn/parallel/__pycache__:
# __init__.cpython-310.pyc
# _functions.cpython-310.pyc
# comm.cpython-310.pyc
# data_parallel.cpython-310.pyc
# distributed.cpython-310.pyc
# parallel_apply.cpython-310.pyc
# replicate.cpython-310.pyc
# scatter_gather.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/qat:
# __init__.py
# __pycache__
# dynamic
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/qat/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/qat/dynamic:
# __init__.py
# __pycache__
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/qat/dynamic/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/qat/dynamic/modules:
# __init__.py
# __pycache__
# linear.py
#
# /install/lib/python3.10/site-packages/torch/nn/qat/dynamic/modules/__pycache__:
# __init__.cpython-310.pyc
# linear.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/qat/modules:
# __init__.py
# __pycache__
# conv.py
# embedding_ops.py
# linear.py
#
# /install/lib/python3.10/site-packages/torch/nn/qat/modules/__pycache__:
# __init__.cpython-310.pyc
# conv.cpython-310.pyc
# embedding_ops.cpython-310.pyc
# linear.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/quantizable:
# __init__.py
# __pycache__
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/quantizable/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/quantizable/modules:
# __init__.py
# __pycache__
# activation.py
# rnn.py
#
# /install/lib/python3.10/site-packages/torch/nn/quantizable/modules/__pycache__:
# __init__.cpython-310.pyc
# activation.cpython-310.pyc
# rnn.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/quantized:
# __init__.py
# __pycache__
# _reference
# dynamic
# functional.py
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/__pycache__:
# __init__.cpython-310.pyc
# functional.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/_reference:
# __init__.py
# __pycache__
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/_reference/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/_reference/modules:
# __init__.py
# __pycache__
# conv.py
# linear.py
# rnn.py
# sparse.py
# utils.py
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/_reference/modules/__pycache__:
# __init__.cpython-310.pyc
# conv.cpython-310.pyc
# linear.cpython-310.pyc
# rnn.cpython-310.pyc
# sparse.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/dynamic:
# __init__.py
# __pycache__
# modules
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/dynamic/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/dynamic/modules:
# __init__.py
# __pycache__
# conv.py
# linear.py
# rnn.py
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/dynamic/modules/__pycache__:
# __init__.cpython-310.pyc
# conv.cpython-310.pyc
# linear.cpython-310.pyc
# rnn.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/modules:
# __init__.py
# __pycache__
# activation.py
# batchnorm.py
# conv.py
# dropout.py
# embedding_ops.py
# functional_modules.py
# linear.py
# normalization.py
# rnn.py
# utils.py
#
# /install/lib/python3.10/site-packages/torch/nn/quantized/modules/__pycache__:
# __init__.cpython-310.pyc
# activation.cpython-310.pyc
# batchnorm.cpython-310.pyc
# conv.cpython-310.pyc
# dropout.cpython-310.pyc
# embedding_ops.cpython-310.pyc
# functional_modules.cpython-310.pyc
# linear.cpython-310.pyc
# normalization.cpython-310.pyc
# rnn.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/utils:
# __init__.py
# __pycache__
# _deprecation_utils.py
# _expanded_weights
# _named_member_accessor.py
# _per_sample_grad.py
# clip_grad.py
# convert_parameters.py
# fusion.py
# init.py
# memory_format.py
# parametrizations.py
# parametrize.py
# prune.py
# rnn.py
# spectral_norm.py
# stateless.py
# weight_norm.py
#
# /install/lib/python3.10/site-packages/torch/nn/utils/__pycache__:
# __init__.cpython-310.pyc
# _deprecation_utils.cpython-310.pyc
# _named_member_accessor.cpython-310.pyc
# _per_sample_grad.cpython-310.pyc
# clip_grad.cpython-310.pyc
# convert_parameters.cpython-310.pyc
# fusion.cpython-310.pyc
# init.cpython-310.pyc
# memory_format.cpython-310.pyc
# parametrizations.cpython-310.pyc
# parametrize.cpython-310.pyc
# prune.cpython-310.pyc
# rnn.cpython-310.pyc
# spectral_norm.cpython-310.pyc
# stateless.cpython-310.pyc
# weight_norm.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/nn/utils/_expanded_weights:
# __init__.py
# __pycache__
# conv_expanded_weights.py
# conv_utils.py
# embedding_expanded_weights.py
# expanded_weights_impl.py
# expanded_weights_utils.py
# group_norm_expanded_weights.py
# instance_norm_expanded_weights.py
# layer_norm_expanded_weights.py
# linear_expanded_weights.py
#
# /install/lib/python3.10/site-packages/torch/nn/utils/_expanded_weights/__pycache__:
# __init__.cpython-310.pyc
# conv_expanded_weights.cpython-310.pyc
# conv_utils.cpython-310.pyc
# embedding_expanded_weights.cpython-310.pyc
# expanded_weights_impl.cpython-310.pyc
# expanded_weights_utils.cpython-310.pyc
# group_norm_expanded_weights.cpython-310.pyc
# instance_norm_expanded_weights.cpython-310.pyc
# layer_norm_expanded_weights.cpython-310.pyc
# linear_expanded_weights.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/numa:
# __init__.py
# __pycache__
# binding.py
#
# /install/lib/python3.10/site-packages/torch/numa/__pycache__:
# __init__.cpython-310.pyc
# binding.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx:
# __init__.py
# __pycache__
# _constants.py
# _flags.py
# _internal
# errors.py
# operators.py
# ops
# symbolic_helper.py
# symbolic_opset10.py
# symbolic_opset11.py
# symbolic_opset12.py
# symbolic_opset13.py
# symbolic_opset14.py
# symbolic_opset15.py
# symbolic_opset16.py
# symbolic_opset17.py
# symbolic_opset18.py
# symbolic_opset19.py
# symbolic_opset20.py
# symbolic_opset7.py
# symbolic_opset8.py
# symbolic_opset9.py
# testing.py
# utils.py
# verification.py
#
# /install/lib/python3.10/site-packages/torch/onnx/__pycache__:
# __init__.cpython-310.pyc
# _constants.cpython-310.pyc
# _flags.cpython-310.pyc
# errors.cpython-310.pyc
# operators.cpython-310.pyc
# symbolic_helper.cpython-310.pyc
# symbolic_opset10.cpython-310.pyc
# symbolic_opset11.cpython-310.pyc
# symbolic_opset12.cpython-310.pyc
# symbolic_opset13.cpython-310.pyc
# symbolic_opset14.cpython-310.pyc
# symbolic_opset15.cpython-310.pyc
# symbolic_opset16.cpython-310.pyc
# symbolic_opset17.cpython-310.pyc
# symbolic_opset18.cpython-310.pyc
# symbolic_opset19.cpython-310.pyc
# symbolic_opset20.cpython-310.pyc
# symbolic_opset7.cpython-310.pyc
# symbolic_opset8.cpython-310.pyc
# symbolic_opset9.cpython-310.pyc
# testing.cpython-310.pyc
# utils.cpython-310.pyc
# verification.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal:
# __init__.py
# __pycache__
# _lazy_import.py
# exporter
# fx
# torchscript_exporter
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/__pycache__:
# __init__.cpython-310.pyc
# _lazy_import.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/exporter:
# __init__.py
# __pycache__
# _analysis.py
# _building.py
# _capture_strategies.py
# _compat.py
# _constants.py
# _core.py
# _decomp.py
# _dispatching.py
# _dynamic_shapes.py
# _errors.py
# _exportable_module.py
# _flags.py
# _fx_passes.py
# _input_observer.py
# _ir_passes.py
# _isolated.py
# _onnx_program.py
# _registration.py
# _reporting.py
# _schemas.py
# _tensors.py
# _testing.py
# _torchlib
# _type_casting.py
# _verification.py
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/exporter/__pycache__:
# __init__.cpython-310.pyc
# _analysis.cpython-310.pyc
# _building.cpython-310.pyc
# _capture_strategies.cpython-310.pyc
# _compat.cpython-310.pyc
# _constants.cpython-310.pyc
# _core.cpython-310.pyc
# _decomp.cpython-310.pyc
# _dispatching.cpython-310.pyc
# _dynamic_shapes.cpython-310.pyc
# _errors.cpython-310.pyc
# _exportable_module.cpython-310.pyc
# _flags.cpython-310.pyc
# _fx_passes.cpython-310.pyc
# _input_observer.cpython-310.pyc
# _ir_passes.cpython-310.pyc
# _isolated.cpython-310.pyc
# _onnx_program.cpython-310.pyc
# _registration.cpython-310.pyc
# _reporting.cpython-310.pyc
# _schemas.cpython-310.pyc
# _tensors.cpython-310.pyc
# _testing.cpython-310.pyc
# _type_casting.cpython-310.pyc
# _verification.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/exporter/_torchlib:
# __init__.py
# __pycache__
# _tensor_typing.py
# _torchlib_registry.py
# ops
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/exporter/_torchlib/__pycache__:
# __init__.cpython-310.pyc
# _tensor_typing.cpython-310.pyc
# _torchlib_registry.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/exporter/_torchlib/ops:
# __init__.py
# __pycache__
# core.py
# hop.py
# nn.py
# symbolic.py
# symops.py
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/exporter/_torchlib/ops/__pycache__:
# __init__.cpython-310.pyc
# core.cpython-310.pyc
# hop.cpython-310.pyc
# nn.cpython-310.pyc
# symbolic.cpython-310.pyc
# symops.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/fx:
# __init__.py
# __pycache__
# _pass.py
# passes
# type_utils.py
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/fx/__pycache__:
# __init__.cpython-310.pyc
# _pass.cpython-310.pyc
# type_utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/fx/passes:
# __init__.py
# __pycache__
# type_promotion.py
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/fx/passes/__pycache__:
# __init__.cpython-310.pyc
# type_promotion.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/torchscript_exporter:
# __init__.py
# __pycache__
# _experimental.py
# _globals.py
# _type_utils.py
# jit_utils.py
# onnx_proto_utils.py
# registration.py
# symbolic_helper.py
# symbolic_opset10.py
# symbolic_opset11.py
# symbolic_opset12.py
# symbolic_opset13.py
# symbolic_opset14.py
# symbolic_opset15.py
# symbolic_opset16.py
# symbolic_opset17.py
# symbolic_opset18.py
# symbolic_opset19.py
# symbolic_opset20.py
# symbolic_opset7.py
# symbolic_opset8.py
# symbolic_opset9.py
# utils.py
# verification.py
#
# /install/lib/python3.10/site-packages/torch/onnx/_internal/torchscript_exporter/__pycache__:
# __init__.cpython-310.pyc
# _experimental.cpython-310.pyc
# _globals.cpython-310.pyc
# _type_utils.cpython-310.pyc
# jit_utils.cpython-310.pyc
# onnx_proto_utils.cpython-310.pyc
# registration.cpython-310.pyc
# symbolic_helper.cpython-310.pyc
# symbolic_opset10.cpython-310.pyc
# symbolic_opset11.cpython-310.pyc
# symbolic_opset12.cpython-310.pyc
# symbolic_opset13.cpython-310.pyc
# symbolic_opset14.cpython-310.pyc
# symbolic_opset15.cpython-310.pyc
# symbolic_opset16.cpython-310.pyc
# symbolic_opset17.cpython-310.pyc
# symbolic_opset18.cpython-310.pyc
# symbolic_opset19.cpython-310.pyc
# symbolic_opset20.cpython-310.pyc
# symbolic_opset7.cpython-310.pyc
# symbolic_opset8.cpython-310.pyc
# symbolic_opset9.cpython-310.pyc
# utils.cpython-310.pyc
# verification.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/onnx/ops:
# __init__.py
# __pycache__
# _dtype_mappings.py
# _impl.py
# _symbolic_impl.py
#
# /install/lib/python3.10/site-packages/torch/onnx/ops/__pycache__:
# __init__.cpython-310.pyc
# _dtype_mappings.cpython-310.pyc
# _impl.cpython-310.pyc
# _symbolic_impl.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/optim:
# __init__.py
# __pycache__
# _adafactor.py
# _functional.py
# _multi_tensor
# _muon.py
# adadelta.py
# adagrad.py
# adam.py
# adamax.py
# adamw.py
# asgd.py
# lbfgs.py
# lr_scheduler.py
# nadam.py
# optimizer.py
# radam.py
# rmsprop.py
# rprop.py
# sgd.py
# sparse_adam.py
# swa_utils.py
#
# /install/lib/python3.10/site-packages/torch/optim/__pycache__:
# __init__.cpython-310.pyc
# _adafactor.cpython-310.pyc
# _functional.cpython-310.pyc
# _muon.cpython-310.pyc
# adadelta.cpython-310.pyc
# adagrad.cpython-310.pyc
# adam.cpython-310.pyc
# adamax.cpython-310.pyc
# adamw.cpython-310.pyc
# asgd.cpython-310.pyc
# lbfgs.cpython-310.pyc
# lr_scheduler.cpython-310.pyc
# nadam.cpython-310.pyc
# optimizer.cpython-310.pyc
# radam.cpython-310.pyc
# rmsprop.cpython-310.pyc
# rprop.cpython-310.pyc
# sgd.cpython-310.pyc
# sparse_adam.cpython-310.pyc
# swa_utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/optim/_multi_tensor:
# __init__.py
# __init__.pyi
# __pycache__
#
# /install/lib/python3.10/site-packages/torch/optim/_multi_tensor/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/package:
# __init__.py
# __pycache__
# _digraph.py
# _directory_reader.py
# _importlib.py
# _mangling.py
# _mock.py
# _package_pickler.py
# _package_unpickler.py
# _stdlib.py
# analyze
# file_structure_representation.py
# find_file_dependencies.py
# glob_group.py
# importer.py
# package_exporter.py
# package_importer.py
#
# /install/lib/python3.10/site-packages/torch/package/__pycache__:
# __init__.cpython-310.pyc
# _digraph.cpython-310.pyc
# _directory_reader.cpython-310.pyc
# _importlib.cpython-310.pyc
# _mangling.cpython-310.pyc
# _mock.cpython-310.pyc
# _package_pickler.cpython-310.pyc
# _package_unpickler.cpython-310.pyc
# _stdlib.cpython-310.pyc
# file_structure_representation.cpython-310.pyc
# find_file_dependencies.cpython-310.pyc
# glob_group.cpython-310.pyc
# importer.cpython-310.pyc
# package_exporter.cpython-310.pyc
# package_importer.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/package/analyze:
# __init__.py
# __pycache__
# find_first_use_of_broken_modules.py
# is_from_package.py
# trace_dependencies.py
#
# /install/lib/python3.10/site-packages/torch/package/analyze/__pycache__:
# __init__.cpython-310.pyc
# find_first_use_of_broken_modules.cpython-310.pyc
# is_from_package.cpython-310.pyc
# trace_dependencies.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/profiler:
# __init__.py
# __pycache__
# _memory_profiler.py
# _pattern_matcher.py
# _utils.py
# itt.py
# profiler.py
# python_tracer.py
#
# /install/lib/python3.10/site-packages/torch/profiler/__pycache__:
# __init__.cpython-310.pyc
# _memory_profiler.cpython-310.pyc
# _pattern_matcher.cpython-310.pyc
# _utils.cpython-310.pyc
# itt.cpython-310.pyc
# profiler.cpython-310.pyc
# python_tracer.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/quantization:
# __init__.py
# __pycache__
# _numeric_suite.py
# _numeric_suite_fx.py
# _quantized_conversions.py
# fake_quantize.py
# fuse_modules.py
# fuser_method_mappings.py
# fx
# observer.py
# qconfig.py
# quant_type.py
# quantization_mappings.py
# quantize.py
# quantize_fx.py
# quantize_jit.py
# stubs.py
# utils.py
#
# /install/lib/python3.10/site-packages/torch/quantization/__pycache__:
# __init__.cpython-310.pyc
# _numeric_suite.cpython-310.pyc
# _numeric_suite_fx.cpython-310.pyc
# _quantized_conversions.cpython-310.pyc
# fake_quantize.cpython-310.pyc
# fuse_modules.cpython-310.pyc
# fuser_method_mappings.cpython-310.pyc
# observer.cpython-310.pyc
# qconfig.cpython-310.pyc
# quant_type.cpython-310.pyc
# quantization_mappings.cpython-310.pyc
# quantize.cpython-310.pyc
# quantize_fx.cpython-310.pyc
# quantize_jit.cpython-310.pyc
# stubs.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/quantization/fx:
# __init__.py
# __pycache__
# _equalize.py
# convert.py
# fuse.py
# fusion_patterns.py
# graph_module.py
# match_utils.py
# pattern_utils.py
# prepare.py
# quantization_patterns.py
# quantization_types.py
# utils.py
#
# /install/lib/python3.10/site-packages/torch/quantization/fx/__pycache__:
# __init__.cpython-310.pyc
# _equalize.cpython-310.pyc
# convert.cpython-310.pyc
# fuse.cpython-310.pyc
# fusion_patterns.cpython-310.pyc
# graph_module.cpython-310.pyc
# match_utils.cpython-310.pyc
# pattern_utils.cpython-310.pyc
# prepare.cpython-310.pyc
# quantization_patterns.cpython-310.pyc
# quantization_types.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/share:
# cmake
#
# /install/lib/python3.10/site-packages/torch/share/cmake:
# ATen
# Caffe2
# Tensorpipe
# Torch
#
# /install/lib/python3.10/site-packages/torch/share/cmake/ATen:
# ATenConfig.cmake
#
# /install/lib/python3.10/site-packages/torch/share/cmake/Caffe2:
# Caffe2Config.cmake
# Caffe2Targets-release.cmake
# Caffe2Targets.cmake
# FindCUDAToolkit.cmake
# FindCUDSS.cmake
# FindCUSPARSELT.cmake
# FindSYCLToolkit.cmake
# Modules_CUDA_fix
# public
#
# /install/lib/python3.10/site-packages/torch/share/cmake/Caffe2/Modules_CUDA_fix:
# FindCUDA.cmake
# FindCUDNN.cmake
# upstream
#
# /install/lib/python3.10/site-packages/torch/share/cmake/Caffe2/Modules_CUDA_fix/upstream:
# CMakeInitializeConfigs.cmake
# FindCUDA
# FindCUDA.cmake
# FindPackageMessage.cmake
#
# /install/lib/python3.10/site-packages/torch/share/cmake/Caffe2/Modules_CUDA_fix/upstream/FindCUDA:
# make2cmake.cmake
# parse_cubin.cmake
# run_nvcc.cmake
# select_compute_arch.cmake
#
# /install/lib/python3.10/site-packages/torch/share/cmake/Caffe2/public:
# LoadHIP.cmake
# cuda.cmake
# gflags.cmake
# glog.cmake
# mkl.cmake
# mkldnn.cmake
# protobuf.cmake
# utils.cmake
# xpu.cmake
#
# /install/lib/python3.10/site-packages/torch/share/cmake/Tensorpipe:
# TensorpipeTargets-release.cmake
# TensorpipeTargets.cmake
#
# /install/lib/python3.10/site-packages/torch/share/cmake/Torch:
# TorchConfig.cmake
# TorchConfigVersion.cmake
#
# /install/lib/python3.10/site-packages/torch/signal:
# __init__.py
# __pycache__
# windows
#
# /install/lib/python3.10/site-packages/torch/signal/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/signal/windows:
# __init__.py
# __pycache__
# windows.py
#
# /install/lib/python3.10/site-packages/torch/signal/windows/__pycache__:
# __init__.cpython-310.pyc
# windows.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/sparse:
# __init__.py
# __pycache__
# _semi_structured_conversions.py
# _semi_structured_ops.py
# _triton_ops.py
# _triton_ops_meta.py
# semi_structured.py
#
# /install/lib/python3.10/site-packages/torch/sparse/__pycache__:
# __init__.cpython-310.pyc
# _semi_structured_conversions.cpython-310.pyc
# _semi_structured_ops.cpython-310.pyc
# _triton_ops.cpython-310.pyc
# _triton_ops_meta.cpython-310.pyc
# semi_structured.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/special:
# __init__.py
# __pycache__
#
# /install/lib/python3.10/site-packages/torch/special/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing:
# __init__.py
# __pycache__
# _comparison.py
# _creation.py
# _internal
# _utils.py
#
# /install/lib/python3.10/site-packages/torch/testing/__pycache__:
# __init__.cpython-310.pyc
# _comparison.cpython-310.pyc
# _creation.cpython-310.pyc
# _utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal:
# __init__.py
# __pycache__
# autocast_test_lists.py
# autograd_function_db.py
# check_kernel_launches.py
# codegen
# common_cuda.py
# common_device_type.py
# common_dist_composable.py
# common_distributed.py
# common_dtype.py
# common_fsdp.py
# common_jit.py
# common_methods_invocations.py
# common_mkldnn.py
# common_modules.py
# common_mps.py
# common_nn.py
# common_ops_unbacked.py
# common_optimizers.py
# common_pruning.py
# common_quantization.py
# common_quantized.py
# common_subclass.py
# common_utils.py
# composite_compliance.py
# custom_op_db.py
# custom_tensor.py
# data
# dist_utils.py
# distributed
# dynamo_pytree_test_utils.py
# dynamo_test_failures.py
# fake_config_module.py
# fake_config_module2.py
# fake_config_module3.py
# generated
# hop_db.py
# hypothesis_utils.py
# inductor_utils.py
# jit_metaprogramming_utils.py
# jit_utils.py
# logging_tensor.py
# logging_utils.py
# opinfo
# optests
# quantization_torch_package_models.py
# static_module.py
# subclasses.py
# test_module
# torchbind_impls.py
# triton_utils.py
# two_tensor.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/__pycache__:
# __init__.cpython-310.pyc
# autocast_test_lists.cpython-310.pyc
# autograd_function_db.cpython-310.pyc
# check_kernel_launches.cpython-310.pyc
# common_cuda.cpython-310.pyc
# common_device_type.cpython-310.pyc
# common_dist_composable.cpython-310.pyc
# common_distributed.cpython-310.pyc
# common_dtype.cpython-310.pyc
# common_fsdp.cpython-310.pyc
# common_jit.cpython-310.pyc
# common_methods_invocations.cpython-310.pyc
# common_mkldnn.cpython-310.pyc
# common_modules.cpython-310.pyc
# common_mps.cpython-310.pyc
# common_nn.cpython-310.pyc
# common_ops_unbacked.cpython-310.pyc
# common_optimizers.cpython-310.pyc
# common_pruning.cpython-310.pyc
# common_quantization.cpython-310.pyc
# common_quantized.cpython-310.pyc
# common_subclass.cpython-310.pyc
# common_utils.cpython-310.pyc
# composite_compliance.cpython-310.pyc
# custom_op_db.cpython-310.pyc
# custom_tensor.cpython-310.pyc
# dist_utils.cpython-310.pyc
# dynamo_pytree_test_utils.cpython-310.pyc
# dynamo_test_failures.cpython-310.pyc
# fake_config_module.cpython-310.pyc
# fake_config_module2.cpython-310.pyc
# fake_config_module3.cpython-310.pyc
# hop_db.cpython-310.pyc
# hypothesis_utils.cpython-310.pyc
# inductor_utils.cpython-310.pyc
# jit_metaprogramming_utils.cpython-310.pyc
# jit_utils.cpython-310.pyc
# logging_tensor.cpython-310.pyc
# logging_utils.cpython-310.pyc
# quantization_torch_package_models.cpython-310.pyc
# static_module.cpython-310.pyc
# subclasses.cpython-310.pyc
# torchbind_impls.cpython-310.pyc
# triton_utils.cpython-310.pyc
# two_tensor.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/codegen:
# __init__.py
# __pycache__
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/codegen/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/data:
# __init__.py
# __pycache__
# network1.py
# network2.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/data/__pycache__:
# __init__.cpython-310.pyc
# network1.cpython-310.pyc
# network2.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed:
# __init__.py
# __pycache__
# _shard
# _tensor
# checkpoint_utils.py
# common_state_dict.py
# ddp_under_dist_autograd_test.py
# distributed_test.py
# distributed_utils.py
# fake_pg.py
# multi_threaded_pg.py
# nn
# rpc
# rpc_utils.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/__pycache__:
# __init__.cpython-310.pyc
# checkpoint_utils.cpython-310.pyc
# common_state_dict.cpython-310.pyc
# ddp_under_dist_autograd_test.cpython-310.pyc
# distributed_test.cpython-310.pyc
# distributed_utils.cpython-310.pyc
# fake_pg.cpython-310.pyc
# multi_threaded_pg.cpython-310.pyc
# rpc_utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/_shard:
# __init__.py
# __pycache__
# sharded_tensor
# test_common.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/_shard/__pycache__:
# __init__.cpython-310.pyc
# test_common.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/_shard/sharded_tensor:
# __init__.py
# __pycache__
# _test_ops_common.py
# _test_st_common.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/_shard/sharded_tensor/__pycache__:
# __init__.cpython-310.pyc
# _test_ops_common.cpython-310.pyc
# _test_st_common.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/_tensor:
# __init__.py
# __pycache__
# common_dtensor.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/_tensor/__pycache__:
# __init__.cpython-310.pyc
# common_dtensor.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/nn:
# __init__.py
# __pycache__
# api
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/nn/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/nn/api:
# __init__.py
# __pycache__
# remote_module_test.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/nn/api/__pycache__:
# __init__.cpython-310.pyc
# remote_module_test.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/rpc:
# __init__.py
# __pycache__
# dist_autograd_test.py
# dist_optimizer_test.py
# examples
# faulty_agent_rpc_test.py
# faulty_rpc_agent_test_fixture.py
# jit
# rpc_agent_test_fixture.py
# rpc_test.py
# tensorpipe_rpc_agent_test_fixture.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/rpc/__pycache__:
# __init__.cpython-310.pyc
# dist_autograd_test.cpython-310.pyc
# dist_optimizer_test.cpython-310.pyc
# faulty_agent_rpc_test.cpython-310.pyc
# faulty_rpc_agent_test_fixture.cpython-310.pyc
# rpc_agent_test_fixture.cpython-310.pyc
# rpc_test.cpython-310.pyc
# tensorpipe_rpc_agent_test_fixture.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/rpc/examples:
# __init__.py
# __pycache__
# parameter_server_test.py
# reinforcement_learning_rpc_test.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/rpc/examples/__pycache__:
# __init__.cpython-310.pyc
# parameter_server_test.cpython-310.pyc
# reinforcement_learning_rpc_test.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/rpc/jit:
# __init__.py
# __pycache__
# dist_autograd_test.py
# rpc_test.py
# rpc_test_faulty.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/distributed/rpc/jit/__pycache__:
# __init__.cpython-310.pyc
# dist_autograd_test.cpython-310.pyc
# rpc_test.cpython-310.pyc
# rpc_test_faulty.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/generated:
# __init__.py
# __pycache__
# annotated_fn_args.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/generated/__pycache__:
# __init__.cpython-310.pyc
# annotated_fn_args.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/opinfo:
# __init__.py
# __pycache__
# core.py
# definitions
# refs.py
# utils.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/opinfo/__pycache__:
# __init__.cpython-310.pyc
# core.cpython-310.pyc
# refs.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/opinfo/definitions:
# __init__.py
# __pycache__
# _masked.py
# fft.py
# linalg.py
# nested.py
# signal.py
# sparse.py
# special.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/opinfo/definitions/__pycache__:
# __init__.cpython-310.pyc
# _masked.cpython-310.pyc
# fft.cpython-310.pyc
# linalg.cpython-310.pyc
# nested.cpython-310.pyc
# signal.cpython-310.pyc
# sparse.cpython-310.pyc
# special.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/optests:
# __init__.py
# __pycache__
# aot_autograd.py
# autograd_registration.py
# fake_tensor.py
# generate_tests.py
# make_fx.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/optests/__pycache__:
# __init__.cpython-310.pyc
# aot_autograd.cpython-310.pyc
# autograd_registration.cpython-310.pyc
# fake_tensor.cpython-310.pyc
# generate_tests.cpython-310.pyc
# make_fx.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/test_module:
# __init__.py
# __pycache__
# future_div.py
# no_future_div.py
#
# /install/lib/python3.10/site-packages/torch/testing/_internal/test_module/__pycache__:
# __init__.cpython-310.pyc
# future_div.cpython-310.pyc
# no_future_div.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils:
# __init__.py
# __pycache__
# _appending_byte_serializer.py
# _config_module.py
# _config_typing.pyi
# _content_store.py
# _contextlib.py
# _cpp_embed_headers.py
# _cpp_extension_versioner.py
# _cxx_pytree.py
# _debug_mode.py
# _device.py
# _dtype_abbrs.py
# _exposed_in.py
# _filelock.py
# _foreach_utils.py
# _functools.py
# _get_clean_triton.py
# _helion.py
# _import_utils.py
# _mode_utils.py
# _ordered_set.py
# _pallas.py
# _python_dispatch.py
# _pytree.py
# _runtime_estimation.py
# _stats.py
# _strobelight
# _sympy
# _thunk.py
# _traceback.py
# _triton.py
# _typing_utils.py
# _zip.py
# backcompat
# backend_registration.py
# benchmark
# bundled_inputs.py
# checkpoint.py
# collect_env.py
# cpp_backtrace.py
# cpp_extension.py
# data
# deterministic.py
# dlpack.py
# file_baton.py
# flop_counter.py
# hipify
# hooks.py
# jit
# mkldnn.py
# mobile_optimizer.py
# model_dump
# model_zoo.py
# module_tracker.py
# serialization
# show_pickle.py
# tensorboard
# throughput_benchmark.py
# viz
# weak.py
#
# /install/lib/python3.10/site-packages/torch/utils/__pycache__:
# __init__.cpython-310.pyc
# _appending_byte_serializer.cpython-310.pyc
# _config_module.cpython-310.pyc
# _content_store.cpython-310.pyc
# _contextlib.cpython-310.pyc
# _cpp_embed_headers.cpython-310.pyc
# _cpp_extension_versioner.cpython-310.pyc
# _cxx_pytree.cpython-310.pyc
# _debug_mode.cpython-310.pyc
# _device.cpython-310.pyc
# _dtype_abbrs.cpython-310.pyc
# _exposed_in.cpython-310.pyc
# _filelock.cpython-310.pyc
# _foreach_utils.cpython-310.pyc
# _functools.cpython-310.pyc
# _get_clean_triton.cpython-310.pyc
# _helion.cpython-310.pyc
# _import_utils.cpython-310.pyc
# _mode_utils.cpython-310.pyc
# _ordered_set.cpython-310.pyc
# _pallas.cpython-310.pyc
# _python_dispatch.cpython-310.pyc
# _pytree.cpython-310.pyc
# _runtime_estimation.cpython-310.pyc
# _stats.cpython-310.pyc
# _thunk.cpython-310.pyc
# _traceback.cpython-310.pyc
# _triton.cpython-310.pyc
# _typing_utils.cpython-310.pyc
# _zip.cpython-310.pyc
# backend_registration.cpython-310.pyc
# bundled_inputs.cpython-310.pyc
# checkpoint.cpython-310.pyc
# collect_env.cpython-310.pyc
# cpp_backtrace.cpython-310.pyc
# cpp_extension.cpython-310.pyc
# deterministic.cpython-310.pyc
# dlpack.cpython-310.pyc
# file_baton.cpython-310.pyc
# flop_counter.cpython-310.pyc
# hooks.cpython-310.pyc
# mkldnn.cpython-310.pyc
# mobile_optimizer.cpython-310.pyc
# model_zoo.cpython-310.pyc
# module_tracker.cpython-310.pyc
# show_pickle.cpython-310.pyc
# throughput_benchmark.cpython-310.pyc
# weak.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/_strobelight:
# __init__.py
# __pycache__
# cli_function_profiler.py
#
# /install/lib/python3.10/site-packages/torch/utils/_strobelight/__pycache__:
# __init__.cpython-310.pyc
# cli_function_profiler.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/_sympy:
# __init__.py
# __pycache__
# functions.py
# interp.py
# numbers.py
# printers.py
# reference.py
# singleton_int.py
# solve.py
# symbol.py
# value_ranges.py
#
# /install/lib/python3.10/site-packages/torch/utils/_sympy/__pycache__:
# __init__.cpython-310.pyc
# functions.cpython-310.pyc
# interp.cpython-310.pyc
# numbers.cpython-310.pyc
# printers.cpython-310.pyc
# reference.cpython-310.pyc
# singleton_int.cpython-310.pyc
# solve.cpython-310.pyc
# symbol.cpython-310.pyc
# value_ranges.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/backcompat:
# __init__.py
# __pycache__
#
# /install/lib/python3.10/site-packages/torch/utils/backcompat/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark:
# __init__.py
# __pycache__
# examples
# op_fuzzers
# utils
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/examples:
# __init__.py
# __pycache__
# compare.py
# fuzzer.py
# op_benchmark.py
# simple_timeit.py
# spectral_ops_fuzz_test.py
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/examples/__pycache__:
# __init__.cpython-310.pyc
# compare.cpython-310.pyc
# fuzzer.cpython-310.pyc
# op_benchmark.cpython-310.pyc
# simple_timeit.cpython-310.pyc
# spectral_ops_fuzz_test.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/op_fuzzers:
# __init__.py
# __pycache__
# binary.py
# sparse_binary.py
# sparse_unary.py
# spectral.py
# unary.py
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/op_fuzzers/__pycache__:
# __init__.cpython-310.pyc
# binary.cpython-310.pyc
# sparse_binary.cpython-310.pyc
# sparse_unary.cpython-310.pyc
# spectral.cpython-310.pyc
# unary.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/utils:
# __init__.py
# __pycache__
# _stubs.py
# common.py
# compare.py
# compile.py
# cpp_jit.py
# fuzzer.py
# sparse_fuzzer.py
# timeit_template.cpp
# timer.py
# valgrind_wrapper
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/utils/__pycache__:
# __init__.cpython-310.pyc
# _stubs.cpython-310.pyc
# common.cpython-310.pyc
# compare.cpython-310.pyc
# compile.cpython-310.pyc
# cpp_jit.cpython-310.pyc
# fuzzer.cpython-310.pyc
# sparse_fuzzer.cpython-310.pyc
# timer.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/utils/valgrind_wrapper:
# __init__.py
# __pycache__
# callgrind.h
# compat_bindings.cpp
# timer_callgrind_template.cpp
# timer_interface.py
# valgrind.h
#
# /install/lib/python3.10/site-packages/torch/utils/benchmark/utils/valgrind_wrapper/__pycache__:
# __init__.cpython-310.pyc
# timer_interface.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/data:
# __init__.py
# __pycache__
# _utils
# backward_compatibility.py
# dataloader.py
# datapipes
# dataset.py
# distributed.py
# graph.py
# graph_settings.py
# sampler.py
#
# /install/lib/python3.10/site-packages/torch/utils/data/__pycache__:
# __init__.cpython-310.pyc
# backward_compatibility.cpython-310.pyc
# dataloader.cpython-310.pyc
# dataset.cpython-310.pyc
# distributed.cpython-310.pyc
# graph.cpython-310.pyc
# graph_settings.cpython-310.pyc
# sampler.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/data/_utils:
# __init__.py
# __pycache__
# collate.py
# fetch.py
# pin_memory.py
# signal_handling.py
# worker.py
#
# /install/lib/python3.10/site-packages/torch/utils/data/_utils/__pycache__:
# __init__.cpython-310.pyc
# collate.cpython-310.pyc
# fetch.cpython-310.pyc
# pin_memory.cpython-310.pyc
# signal_handling.cpython-310.pyc
# worker.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes:
# __init__.py
# __pycache__
# _decorator.py
# _hook_iterator.py
# _typing.py
# dataframe
# datapipe.py
# datapipe.pyi
# gen_pyi.py
# iter
# map
# utils
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/__pycache__:
# __init__.cpython-310.pyc
# _decorator.cpython-310.pyc
# _hook_iterator.cpython-310.pyc
# _typing.cpython-310.pyc
# datapipe.cpython-310.pyc
# gen_pyi.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/dataframe:
# __init__.py
# __pycache__
# dataframe_wrapper.py
# dataframes.py
# datapipes.py
# structures.py
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/dataframe/__pycache__:
# __init__.cpython-310.pyc
# dataframe_wrapper.cpython-310.pyc
# dataframes.cpython-310.pyc
# datapipes.cpython-310.pyc
# structures.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/iter:
# __init__.py
# __pycache__
# callable.py
# combinatorics.py
# combining.py
# filelister.py
# fileopener.py
# grouping.py
# routeddecoder.py
# selecting.py
# sharding.py
# streamreader.py
# utils.py
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/__pycache__:
# __init__.cpython-310.pyc
# callable.cpython-310.pyc
# combinatorics.cpython-310.pyc
# combining.cpython-310.pyc
# filelister.cpython-310.pyc
# fileopener.cpython-310.pyc
# grouping.cpython-310.pyc
# routeddecoder.cpython-310.pyc
# selecting.cpython-310.pyc
# sharding.cpython-310.pyc
# streamreader.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/map:
# __init__.py
# __pycache__
# callable.py
# combinatorics.py
# combining.py
# grouping.py
# utils.py
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/map/__pycache__:
# __init__.cpython-310.pyc
# callable.cpython-310.pyc
# combinatorics.cpython-310.pyc
# combining.cpython-310.pyc
# grouping.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/utils:
# __init__.py
# __pycache__
# common.py
# decoder.py
# snapshot.py
#
# /install/lib/python3.10/site-packages/torch/utils/data/datapipes/utils/__pycache__:
# __init__.cpython-310.pyc
# common.cpython-310.pyc
# decoder.cpython-310.pyc
# snapshot.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/hipify:
# __init__.py
# __pycache__
# constants.py
# cuda_to_hip_mappings.py
# hipify_python.py
# version.py
#
# /install/lib/python3.10/site-packages/torch/utils/hipify/__pycache__:
# __init__.cpython-310.pyc
# constants.cpython-310.pyc
# cuda_to_hip_mappings.cpython-310.pyc
# hipify_python.cpython-310.pyc
# version.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/jit:
# __init__.py
# __pycache__
# log_extract.py
#
# /install/lib/python3.10/site-packages/torch/utils/jit/__pycache__:
# __init__.cpython-310.pyc
# log_extract.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/model_dump:
# __init__.py
# __main__.py
# __pycache__
# code.js
# htm.mjs
# preact.mjs
# skeleton.html
#
# /install/lib/python3.10/site-packages/torch/utils/model_dump/__pycache__:
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/serialization:
# __init__.py
# __pycache__
# config.py
#
# /install/lib/python3.10/site-packages/torch/utils/serialization/__pycache__:
# __init__.cpython-310.pyc
# config.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/tensorboard:
# __init__.py
# __pycache__
# _convert_np.py
# _embedding.py
# _onnx_graph.py
# _proto_graph.py
# _pytorch_graph.py
# _utils.py
# summary.py
# writer.py
#
# /install/lib/python3.10/site-packages/torch/utils/tensorboard/__pycache__:
# __init__.cpython-310.pyc
# _convert_np.cpython-310.pyc
# _embedding.cpython-310.pyc
# _onnx_graph.cpython-310.pyc
# _proto_graph.cpython-310.pyc
# _pytorch_graph.cpython-310.pyc
# _utils.cpython-310.pyc
# summary.cpython-310.pyc
# writer.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/utils/viz:
# __init__.py
# __pycache__
# _cycles.py
#
# /install/lib/python3.10/site-packages/torch/utils/viz/__pycache__:
# __init__.cpython-310.pyc
# _cycles.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch/xpu:
# __init__.py
# __pycache__
# _gpu_trace.py
# _utils.py
# graphs.py
# memory.py
# random.py
# streams.py
#
# /install/lib/python3.10/site-packages/torch/xpu/__pycache__:
# __init__.cpython-310.pyc
# _gpu_trace.cpython-310.pyc
# _utils.cpython-310.pyc
# graphs.cpython-310.pyc
# memory.cpython-310.pyc
# random.cpython-310.pyc
# streams.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torch-2.11.0.dist-info:
# INSTALLER
# METADATA
# RECORD
# WHEEL
# entry_points.txt
# licenses
# top_level.txt
#
# /install/lib/python3.10/site-packages/torch-2.11.0.dist-info/licenses:
# LICENSE
# NOTICE
#
# /install/lib/python3.10/site-packages/torchgen:
# __init__.py
# __pycache__
# aoti
# api
# code_template.py
# context.py
# dest
# gen.py
# gen_aoti_c_shim.py
# gen_backend_stubs.py
# gen_functionalization_type.py
# gen_lazy_tensor.py
# gen_schema_utils.py
# gen_vmap_plumbing.py
# local.py
# model.py
# native_function_generation.py
# operator_versions
# packaged
# selective_build
# static_runtime
# utils.py
# yaml_utils.py
#
# /install/lib/python3.10/site-packages/torchgen/__pycache__:
# __init__.cpython-310.pyc
# code_template.cpython-310.pyc
# context.cpython-310.pyc
# gen.cpython-310.pyc
# gen_aoti_c_shim.cpython-310.pyc
# gen_backend_stubs.cpython-310.pyc
# gen_functionalization_type.cpython-310.pyc
# gen_lazy_tensor.cpython-310.pyc
# gen_schema_utils.cpython-310.pyc
# gen_vmap_plumbing.cpython-310.pyc
# local.cpython-310.pyc
# model.cpython-310.pyc
# native_function_generation.cpython-310.pyc
# utils.cpython-310.pyc
# yaml_utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torchgen/aoti:
# __init__.py
# __pycache__
# fallback_ops.py
#
# /install/lib/python3.10/site-packages/torchgen/aoti/__pycache__:
# __init__.cpython-310.pyc
# fallback_ops.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torchgen/api:
# __init__.py
# __pycache__
# autograd.py
# cpp.py
# dispatcher.py
# functionalization.py
# lazy.py
# meta.py
# native.py
# python.py
# structured.py
# translate.py
# types
# ufunc.py
# unboxing.py
#
# /install/lib/python3.10/site-packages/torchgen/api/__pycache__:
# __init__.cpython-310.pyc
# autograd.cpython-310.pyc
# cpp.cpython-310.pyc
# dispatcher.cpython-310.pyc
# functionalization.cpython-310.pyc
# lazy.cpython-310.pyc
# meta.cpython-310.pyc
# native.cpython-310.pyc
# python.cpython-310.pyc
# structured.cpython-310.pyc
# translate.cpython-310.pyc
# ufunc.cpython-310.pyc
# unboxing.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torchgen/api/types:
# __init__.py
# __pycache__
# signatures.py
# types.py
# types_base.py
#
# /install/lib/python3.10/site-packages/torchgen/api/types/__pycache__:
# __init__.cpython-310.pyc
# signatures.cpython-310.pyc
# types.cpython-310.pyc
# types_base.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torchgen/dest:
# __init__.py
# __pycache__
# lazy_ir.py
# lazy_ts_lowering.py
# native_functions.py
# register_dispatch_key.py
# ufunc.py
#
# /install/lib/python3.10/site-packages/torchgen/dest/__pycache__:
# __init__.cpython-310.pyc
# lazy_ir.cpython-310.pyc
# lazy_ts_lowering.cpython-310.pyc
# native_functions.cpython-310.pyc
# register_dispatch_key.cpython-310.pyc
# ufunc.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torchgen/operator_versions:
# __init__.py
# __pycache__
# gen_mobile_upgraders.py
# gen_mobile_upgraders_constant.py
#
# /install/lib/python3.10/site-packages/torchgen/operator_versions/__pycache__:
# __init__.cpython-310.pyc
# gen_mobile_upgraders.cpython-310.pyc
# gen_mobile_upgraders_constant.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/torchgen/packaged:
# ATen
# autograd
#
# /install/lib/python3.10/site-packages/torchgen/packaged/ATen:
# native
# templates
#
# /install/lib/python3.10/site-packages/torchgen/packaged/ATen/native:
# native_functions.yaml
# tags.yaml
#
# /install/lib/python3.10/site-packages/torchgen/packaged/ATen/templates:
# ATenOpList.cpp
# CompositeViewCopyKernels.cpp
# DispatchKeyFunction.h
# DispatchKeyFunctions.h
# DispatchKeyFunctions_inl.h
# DispatchKeyNativeFunctions.cpp
# DispatchKeyNativeFunctions.h
# Function.h
# FunctionalInverses.h
# Functions.cpp
# Functions.h
# LazyIr.h
# LazyNonNativeIr.h
# MethodOperators.h
# NativeFunction.h
# NativeFunctions.h
# NativeMetaFunction.h
# NativeMetaFunctions.h
# Operator.h
# Operators.cpp
# Operators.h
# RedispatchFunctions.cpp
# RedispatchFunctions.h
# RegisterBackendSelect.cpp
# RegisterCodegenUnboxedKernels.cpp
# RegisterDispatchDefinitions.ini
# RegisterDispatchKey.cpp
# RegisterFunctionalization.cpp
# RegisterSchema.cpp
# RegistrationDeclarations.h
# TensorBody.h
# TensorMethods.cpp
# UfuncCPU.cpp
# UfuncCPUKernel.cpp
# UfuncCUDA.cu
# UnboxingFunctions.cpp
# UnboxingFunctions.h
# ViewMetaClasses.cpp
# ViewMetaClasses.h
# ViewMetaClassesPythonBinding.cpp
# aten_interned_strings.h
# enum_tag.h
#
# /install/lib/python3.10/site-packages/torchgen/packaged/autograd:
# BUILD.bazel
# README.md
# __init__.py
# __pycache__
# build.bzl
# context.py
# deprecated.yaml
# derivatives.yaml
# gen_annotated_fn_args.py
# gen_autograd.py
# gen_autograd_functions.py
# gen_inplace_or_view_type.py
# gen_python_functions.py
# gen_trace_type.py
# gen_variable_factories.py
# gen_variable_type.py
# gen_view_funcs.py
# load_derivatives.py
# templates
#
# /install/lib/python3.10/site-packages/torchgen/packaged/autograd/__pycache__:
# __init__.cpython-310.pyc
# context.cpython-310.pyc
# gen_annotated_fn_args.cpython-310.pyc
# gen_autograd.cpython-310.pyc
# gen_autograd_functions.cpython-310.pyc
# gen_inplace_or_view_type.cpython-310.pyc
# gen_python_functions.cpython-310.pyc
# gen_trace_type.cpython-310.pyc
# gen_variable_factories.cpython-310.pyc
# gen_variable_type.cpython-310.pyc
# gen_view_funcs.cpython-310.pyc
# ...
# __init__.cpython-310.pyc
# pyopenssl.cpython-310.pyc
# socks.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/urllib3/contrib/emscripten:
# __init__.py
# __pycache__
# connection.py
# emscripten_fetch_worker.js
# fetch.py
# request.py
# response.py
#
# /install/lib/python3.10/site-packages/urllib3/contrib/emscripten/__pycache__:
# __init__.cpython-310.pyc
# connection.cpython-310.pyc
# fetch.cpython-310.pyc
# request.cpython-310.pyc
# response.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/urllib3/http2:
# __init__.py
# __pycache__
# connection.py
# probe.py
#
# /install/lib/python3.10/site-packages/urllib3/http2/__pycache__:
# __init__.cpython-310.pyc
# connection.cpython-310.pyc
# probe.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/urllib3/util:
# __init__.py
# __pycache__
# connection.py
# proxy.py
# request.py
# response.py
# retry.py
# ssl_.py
# ssl_match_hostname.py
# ssltransport.py
# timeout.py
# url.py
# util.py
# wait.py
#
# /install/lib/python3.10/site-packages/urllib3/util/__pycache__:
# __init__.cpython-310.pyc
# connection.cpython-310.pyc
# proxy.cpython-310.pyc
# request.cpython-310.pyc
# response.cpython-310.pyc
# retry.cpython-310.pyc
# ssl_.cpython-310.pyc
# ssl_match_hostname.cpython-310.pyc
# ssltransport.cpython-310.pyc
# timeout.cpython-310.pyc
# url.cpython-310.pyc
# util.cpython-310.pyc
# wait.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/urllib3-2.6.3.dist-info:
# INSTALLER
# METADATA
# RECORD
# WHEEL
# licenses
#
# /install/lib/python3.10/site-packages/urllib3-2.6.3.dist-info/licenses:
# LICENSE.txt
#
# /install/lib/python3.10/site-packages/uvicorn:
# __init__.py
# __main__.py
# __pycache__
# _compat.py
# _subprocess.py
# _types.py
# config.py
# importer.py
# lifespan
# logging.py
# loops
# main.py
# middleware
# protocols
# py.typed
# server.py
# supervisors
# workers.py
#
# /install/lib/python3.10/site-packages/uvicorn/__pycache__:
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
# _compat.cpython-310.pyc
# _subprocess.cpython-310.pyc
# _types.cpython-310.pyc
# config.cpython-310.pyc
# importer.cpython-310.pyc
# logging.cpython-310.pyc
# main.cpython-310.pyc
# server.cpython-310.pyc
# workers.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/uvicorn/lifespan:
# __init__.py
# __pycache__
# off.py
# on.py
#
# /install/lib/python3.10/site-packages/uvicorn/lifespan/__pycache__:
# __init__.cpython-310.pyc
# off.cpython-310.pyc
# on.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/uvicorn/loops:
# __init__.py
# __pycache__
# asyncio.py
# auto.py
# uvloop.py
#
# /install/lib/python3.10/site-packages/uvicorn/loops/__pycache__:
# __init__.cpython-310.pyc
# asyncio.cpython-310.pyc
# auto.cpython-310.pyc
# uvloop.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/uvicorn/middleware:
# __init__.py
# __pycache__
# asgi2.py
# message_logger.py
# proxy_headers.py
# wsgi.py
#
# /install/lib/python3.10/site-packages/uvicorn/middleware/__pycache__:
# __init__.cpython-310.pyc
# asgi2.cpython-310.pyc
# message_logger.cpython-310.pyc
# proxy_headers.cpython-310.pyc
# wsgi.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/uvicorn/protocols:
# __init__.py
# __pycache__
# http
# utils.py
# websockets
#
# /install/lib/python3.10/site-packages/uvicorn/protocols/__pycache__:
# __init__.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/uvicorn/protocols/http:
# __init__.py
# __pycache__
# auto.py
# flow_control.py
# h11_impl.py
# httptools_impl.py
#
# /install/lib/python3.10/site-packages/uvicorn/protocols/http/__pycache__:
# __init__.cpython-310.pyc
# auto.cpython-310.pyc
# flow_control.cpython-310.pyc
# h11_impl.cpython-310.pyc
# httptools_impl.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/uvicorn/protocols/websockets:
# __init__.py
# __pycache__
# auto.py
# websockets_impl.py
# websockets_sansio_impl.py
# wsproto_impl.py
#
# /install/lib/python3.10/site-packages/uvicorn/protocols/websockets/__pycache__:
# __init__.cpython-310.pyc
# auto.cpython-310.pyc
# websockets_impl.cpython-310.pyc
# websockets_sansio_impl.cpython-310.pyc
# wsproto_impl.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/uvicorn/supervisors:
# __init__.py
# __pycache__
# basereload.py
# multiprocess.py
# statreload.py
# watchfilesreload.py
#
# /install/lib/python3.10/site-packages/uvicorn/supervisors/__pycache__:
# __init__.cpython-310.pyc
# basereload.cpython-310.pyc
# multiprocess.cpython-310.pyc
# statreload.cpython-310.pyc
# watchfilesreload.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/uvicorn-0.44.0.dist-info:
# INSTALLER
# METADATA
# RECORD
# WHEEL
# entry_points.txt
# licenses
#
# /install/lib/python3.10/site-packages/uvicorn-0.44.0.dist-info/licenses:
# LICENSE.md
#
# /install/lib/python3.10/site-packages/werkzeug:
# __init__.py
# __pycache__
# _internal.py
# _reloader.py
# datastructures
# debug
# exceptions.py
# formparser.py
# http.py
# local.py
# middleware
# py.typed
# routing
# sansio
# security.py
# serving.py
# test.py
# testapp.py
# urls.py
# user_agent.py
# utils.py
# wrappers
# wsgi.py
#
# /install/lib/python3.10/site-packages/werkzeug/__pycache__:
# __init__.cpython-310.pyc
# _internal.cpython-310.pyc
# _reloader.cpython-310.pyc
# exceptions.cpython-310.pyc
# formparser.cpython-310.pyc
# http.cpython-310.pyc
# local.cpython-310.pyc
# security.cpython-310.pyc
# serving.cpython-310.pyc
# test.cpython-310.pyc
# testapp.cpython-310.pyc
# urls.cpython-310.pyc
# user_agent.cpython-310.pyc
# utils.cpython-310.pyc
# wsgi.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/werkzeug/datastructures:
# __init__.py
# __pycache__
# accept.py
# auth.py
# cache_control.py
# csp.py
# etag.py
# file_storage.py
# headers.py
# mixins.py
# range.py
# structures.py
#
# /install/lib/python3.10/site-packages/werkzeug/datastructures/__pycache__:
# __init__.cpython-310.pyc
# accept.cpython-310.pyc
# auth.cpython-310.pyc
# cache_control.cpython-310.pyc
# csp.cpython-310.pyc
# etag.cpython-310.pyc
# file_storage.cpython-310.pyc
# headers.cpython-310.pyc
# mixins.cpython-310.pyc
# range.cpython-310.pyc
# structures.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/werkzeug/debug:
# __init__.py
# __pycache__
# console.py
# repr.py
# shared
# tbtools.py
#
# /install/lib/python3.10/site-packages/werkzeug/debug/__pycache__:
# __init__.cpython-310.pyc
# console.cpython-310.pyc
# repr.cpython-310.pyc
# tbtools.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/werkzeug/debug/shared:
# ICON_LICENSE.md
# console.png
# debugger.js
# less.png
# more.png
# style.css
#
# /install/lib/python3.10/site-packages/werkzeug/middleware:
# __init__.py
# __pycache__
# dispatcher.py
# http_proxy.py
# lint.py
# profiler.py
# proxy_fix.py
# shared_data.py
#
# /install/lib/python3.10/site-packages/werkzeug/middleware/__pycache__:
# __init__.cpython-310.pyc
# dispatcher.cpython-310.pyc
# http_proxy.cpython-310.pyc
# lint.cpython-310.pyc
# profiler.cpython-310.pyc
# proxy_fix.cpython-310.pyc
# shared_data.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/werkzeug/routing:
# __init__.py
# __pycache__
# converters.py
# exceptions.py
# map.py
# matcher.py
# rules.py
#
# /install/lib/python3.10/site-packages/werkzeug/routing/__pycache__:
# __init__.cpython-310.pyc
# converters.cpython-310.pyc
# exceptions.cpython-310.pyc
# map.cpython-310.pyc
# matcher.cpython-310.pyc
# rules.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/werkzeug/sansio:
# __init__.py
# __pycache__
# http.py
# multipart.py
# request.py
# response.py
# utils.py
#
# /install/lib/python3.10/site-packages/werkzeug/sansio/__pycache__:
# __init__.cpython-310.pyc
# http.cpython-310.pyc
# multipart.cpython-310.pyc
# request.cpython-310.pyc
# response.cpython-310.pyc
# utils.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/werkzeug/wrappers:
# __init__.py
# __pycache__
# request.py
# response.py
#
# /install/lib/python3.10/site-packages/werkzeug/wrappers/__pycache__:
# __init__.cpython-310.pyc
# request.cpython-310.pyc
# response.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/werkzeug-3.1.8.dist-info:
# INSTALLER
# METADATA
# RECORD
# WHEEL
# licenses
#
# /install/lib/python3.10/site-packages/werkzeug-3.1.8.dist-info/licenses:
# LICENSE.txt
#
# /install/lib/python3.10/site-packages/yacs:
# __init__.py
# __pycache__
# config.py
# tests.py
#
# /install/lib/python3.10/site-packages/yacs/__pycache__:
# __init__.cpython-310.pyc
# config.cpython-310.pyc
# tests.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yacs-0.1.8.dist-info:
# INSTALLER
# LICENSE
# METADATA
# NOTICE
# RECORD
# REQUESTED
# WHEEL
# top_level.txt
#
# /install/lib/python3.10/site-packages/yaml:
# __init__.py
# __pycache__
# _yaml.cpython-310-x86_64-linux-gnu.so
# composer.py
# constructor.py
# cyaml.py
# dumper.py
# emitter.py
# error.py
# events.py
# loader.py
# nodes.py
# parser.py
# reader.py
# representer.py
# resolver.py
# scanner.py
# serializer.py
# tokens.py
#
# /install/lib/python3.10/site-packages/yaml/__pycache__:
# __init__.cpython-310.pyc
# composer.cpython-310.pyc
# constructor.cpython-310.pyc
# cyaml.cpython-310.pyc
# dumper.cpython-310.pyc
# emitter.cpython-310.pyc
# error.cpython-310.pyc
# events.cpython-310.pyc
# loader.cpython-310.pyc
# nodes.cpython-310.pyc
# parser.cpython-310.pyc
# reader.cpython-310.pyc
# representer.cpython-310.pyc
# resolver.cpython-310.pyc
# scanner.cpython-310.pyc
# serializer.cpython-310.pyc
# tokens.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapf:
# __init__.py
# __main__.py
# __pycache__
# _version.py
# pyparser
# pytree
# yapflib
#
# /install/lib/python3.10/site-packages/yapf/__pycache__:
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
# _version.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapf/pyparser:
# __init__.py
# __pycache__
# pyparser.py
# pyparser_utils.py
# split_penalty_visitor.py
#
# /install/lib/python3.10/site-packages/yapf/pyparser/__pycache__:
# __init__.cpython-310.pyc
# pyparser.cpython-310.pyc
# pyparser_utils.cpython-310.pyc
# split_penalty_visitor.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapf/pytree:
# __init__.py
# __pycache__
# blank_line_calculator.py
# comment_splicer.py
# continuation_splicer.py
# pytree_unwrapper.py
# pytree_utils.py
# pytree_visitor.py
# split_penalty.py
# subtype_assigner.py
#
# /install/lib/python3.10/site-packages/yapf/pytree/__pycache__:
# __init__.cpython-310.pyc
# blank_line_calculator.cpython-310.pyc
# comment_splicer.cpython-310.pyc
# continuation_splicer.cpython-310.pyc
# pytree_unwrapper.cpython-310.pyc
# pytree_utils.cpython-310.pyc
# pytree_visitor.cpython-310.pyc
# split_penalty.cpython-310.pyc
# subtype_assigner.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapf/yapflib:
# __init__.py
# __pycache__
# errors.py
# file_resources.py
# format_decision_state.py
# format_token.py
# identify_container.py
# line_joiner.py
# logical_line.py
# object_state.py
# reformatter.py
# split_penalty.py
# style.py
# subtypes.py
# yapf_api.py
#
# /install/lib/python3.10/site-packages/yapf/yapflib/__pycache__:
# __init__.cpython-310.pyc
# errors.cpython-310.pyc
# file_resources.cpython-310.pyc
# format_decision_state.cpython-310.pyc
# format_token.cpython-310.pyc
# identify_container.cpython-310.pyc
# line_joiner.cpython-310.pyc
# logical_line.cpython-310.pyc
# object_state.cpython-310.pyc
# reformatter.cpython-310.pyc
# split_penalty.cpython-310.pyc
# style.cpython-310.pyc
# subtypes.cpython-310.pyc
# yapf_api.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapf-0.43.0.dist-info:
# AUTHORS
# INSTALLER
# LICENSE
# METADATA
# RECORD
# WHEEL
# entry_points.txt
# top_level.txt
#
# /install/lib/python3.10/site-packages/yapf_third_party:
# __init__.py
# __pycache__
# _ylib2to3
# yapf_diff
#
# /install/lib/python3.10/site-packages/yapf_third_party/__pycache__:
# __init__.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapf_third_party/_ylib2to3:
# Grammar.txt
# LICENSE
# PatternGrammar.txt
# __init__.py
# __pycache__
# fixer_base.py
# fixer_util.py
# patcomp.py
# pgen2
# pygram.py
# pytree.py
#
# /install/lib/python3.10/site-packages/yapf_third_party/_ylib2to3/__pycache__:
# __init__.cpython-310.pyc
# fixer_base.cpython-310.pyc
# fixer_util.cpython-310.pyc
# patcomp.cpython-310.pyc
# pygram.cpython-310.pyc
# pytree.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapf_third_party/_ylib2to3/pgen2:
# __init__.py
# __pycache__
# conv.py
# driver.py
# grammar.py
# literals.py
# parse.py
# pgen.py
# token.py
# tokenize.py
#
# /install/lib/python3.10/site-packages/yapf_third_party/_ylib2to3/pgen2/__pycache__:
# __init__.cpython-310.pyc
# conv.cpython-310.pyc
# driver.cpython-310.pyc
# grammar.cpython-310.pyc
# literals.cpython-310.pyc
# parse.cpython-310.pyc
# pgen.cpython-310.pyc
# token.cpython-310.pyc
# tokenize.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapf_third_party/yapf_diff:
# LICENSE
# __init__.py
# __pycache__
# yapf_diff.py
#
# /install/lib/python3.10/site-packages/yapf_third_party/yapf_diff/__pycache__:
# __init__.cpython-310.pyc
# yapf_diff.cpython-310.pyc
#
# /install/lib/python3.10/site-packages/yapftests:
# __init__.py
# __pycache__
# blank_line_calculator_test.py
# comment_splicer_test.py
# file_resources_test.py
# format_decision_state_test.py
# format_token_test.py
# line_joiner_test.py
# logical_line_test.py
# main_test.py
# pytree_unwrapper_test.py
# pytree_utils_test.py
# pytree_visitor_test.py
# reformatter_basic_test.py
# reformatter_buganizer_test.py
# reformatter_facebook_test.py
# reformatter_pep8_test.py
# reformatter_python3_test.py
# reformatter_style_config_test.py
# split_penalty_test.py
# style_test.py
# subtype_assigner_test.py
# utils.py
# yapf_test.py
# yapf_test_helper.py
#
# /install/lib/python3.10/site-packages/yapftests/__pycache__:
# __init__.cpython-310.pyc
# blank_line_calculator_test.cpython-310.pyc
# comment_splicer_test.cpython-310.pyc
# file_resources_test.cpython-310.pyc
# format_decision_state_test.cpython-310.pyc
# format_token_test.cpython-310.pyc
# line_joiner_test.cpython-310.pyc
# logical_line_test.cpython-310.pyc
# main_test.cpython-310.pyc
# pytree_unwrapper_test.cpython-310.pyc
# pytree_utils_test.cpython-310.pyc
# pytree_visitor_test.cpython-310.pyc
# reformatter_basic_test.cpython-310.pyc
# reformatter_buganizer_test.cpython-310.pyc
# reformatter_facebook_test.cpython-310.pyc
# reformatter_pep8_test.cpython-310.pyc
# reformatter_python3_test.cpython-310.pyc
# reformatter_style_config_test.cpython-310.pyc
# split_penalty_test.cpython-310.pyc
# style_test.cpython-310.pyc
# subtype_assigner_test.cpython-310.pyc
# utils.cpython-310.pyc
# yapf_test.cpython-310.pyc
# yapf_test_helper.cpython-310.pyc
# Removing intermediate container 40b5982ef619
#  ---> 3a0d90aab0a5
# Step 11/17 : FROM python:3.10-slim
#  ---> 94717d9fb8a0
# Step 12/17 : ENV PYTHONPATH=/usr/local/lib/python3.10/site-packages:/usr/local/lib/python3.10/dist-packages:$PYTHONPATH
#  ---> Running in 4c99df55d2e0
# Removing intermediate container 4c99df55d2e0
#  ---> c4ec10c4a8a0
# Step 13/17 : ENV LD_LIBRARY_PATH=/usr/local/lib/python3.10/site-packages/nvidia/cu13/lib:/usr/local/lib/python3.10/site-packages/nvidia/cublas/lib
#  ---> Running in 995805de7cd8
# Removing intermediate container 995805de7cd8
#  ---> 3effc90d3423
# Step 14/17 : COPY --from=builder /install/lib/python3.10/site-packages /usr/local/lib/python3.10/site-packages
#  ---> 26174654c88b
# Step 15/17 : COPY . /app
#  ---> 8ba66bfd06b3
# Step 16/17 : WORKDIR /app
#  ---> Running in 2b3e22bbed83
# Removing intermediate container 2b3e22bbed83
#  ---> 4593b356bb6b
# Step 17/17 : CMD ["python", "app_sadtalker.py"]
#  ---> Running in 6a3ae8b3336e
# Removing intermediate container 6a3ae8b3336e
#  ---> 4f7f152de739
# Successfully built 4f7f152de739
# Successfully tagged europe-west1-docker.pkg.dev/project-46810a95-b6e5-47e4-adb/cloud-run-source-deploy/gradio-test:latest
# PUSH
# Pushing europe-west1-docker.pkg.dev/project-46810a95-b6e5-47e4-adb/cloud-run-source-deploy/gradio-test:latest
# The push refers to repository [europe-west1-docker.pkg.dev/project-46810a95-b6e5-47e4-adb/cloud-run-source-deploy/gradio-test]
# b8d6359387fa: Preparing
# a01b8a8d0d50: Preparing
# 39b3f7475ebd: Preparing
# af8e2cb9023a: Preparing
# e35db0322204: Preparing
# 60e70dddd9ea: Preparing
# e35db0322204: Layer already exists
# af8e2cb9023a: Layer already exists
# 39b3f7475ebd: Layer already exists
# 60e70dddd9ea: Pushed
# b8d6359387fa: Pushed
# a01b8a8d0d50: Pushed
# latest: digest: sha256:51a836113e70cc687ee0875fc7b145d73b65ea7b39d686b668dabaad1dc134c7 size: 1587
# DONE
#
# ID                                    CREATE_TIME                DURATION  SOURCE                                                                                                        IMAGES                                                                                                    STATUS
# 0747c604-f5bd-4c12-806d-cf75d2d2fae2  2026-04-17T16:04:36+00:00  23M3S     gs://project-46810a95-b6e5-47e4-adb_cloudbuild/source/1776441659.947425-f57f51317df0488a92bbdbfcff8071fc.tgz  europe-west1-docker.pkg.dev/project-46810a95-b6e5-47e4-adb/cloud-run-source-deploy/gradio-test (+1 more)  SUCCESS
# Script done.

# %% [markdown]
# # CLOUD RUN Section

# %%
# !bash -x ../z5-run.sh

# %% [markdown]
# # BUILD LOG Section

# %%
# !gcloud builds list --limit=10 --region=europe-west1

# %%
# !gcloud beta builds log "5d507813-da64-4f6c-9081-90a37df98562" --stream --region europe-west1| grep  "libcuda"

# %% [markdown]
# # GIT Section

# %%
# %cd /content/drive/MyDrive/SadTalker_Patched_2026
# !git status -uno

# %cd /content/SadTalker
# !git status -uno

# %%
import gradio as gr

def gruß_funktion(name):
    return f"Hallo {name}!"

demo = gr.Interface(fn=gruß_funktion, inputs="text", outputs="text")
demo.launch()

# %% [markdown]
# # gradio_app Section

# %%
# %cd /content

import os

# Verzeichnis erstellen
os.makedirs('gradio_app', exist_ok=True)

# 1. Die Hauptdatei (app.py) erstellen
with open('gradio_app/main.py', 'w') as f:
    f.write("""
import gradio as gr
import os

def gruß_funktion(name):
    return f"Hallo {name}!"

demo = gr.Interface(fn=gruß_funktion, inputs="text", outputs="text")

if __name__ == "__main__":
    # WICHTIG: Port 8080 für Cloud Run
    demo.launch(server_name="0.0.0.0", server_port=8080)
""")

# 2. Die Abhängigkeiten (requirements.txt) erstellen
with open('gradio_app/requirements.txt', 'w') as f:
    f.write("gradio\n")

# %%
# Wechsel in den Ordner und deploye
# %cd gradio_app
# !gcloud run deploy gradio-service \
  --source . \
  --region europe-west1 \
  --allow-unauthenticated

# %% [markdown]
# # DEPLOY_ZONE OBSOLETE Section

# %%
# Lokale Umgebung bereinigen
# !rm -rf /content/deploy_zone
# !mkdir -p /content/deploy_zone

# Nur die notwendigen Dateien aus dem Drive kopieren
# Hinweis: Kopieren Sie die Modelle einzeln, wenn es zu viele sind
# !cp /content/drive/MyDrive/SadTalker_Patched_2026/app_sadtalker.py /content/deploy_zone/
# !cp -r /content/drive/MyDrive/SadTalker_Patched_2026/src /content/deploy_zone/
# Falls Sie eine requirements.txt haben:
# !cp /content/drive/MyDrive/SadTalker_Patched_2026/requirements.txt /content/deploy_zone/ 2>/dev/null

# Procfile direkt dort erstellen
# !echo "web: python app_sadtalker.py" > /content/deploy_zone/Procfile

# %%
# %cd /content/deploy_zone
# !echo "drive/" > .dockerignore
# !echo ".ipynb_checkpoints" >> .dockerignore
# !echo "__pycache__" >> .dockerignore

# %%
# Dockerfile erstellen

# %%
# !pip freeze > /content/deploy_zone/requirements.txt

# %%
# !gcloud run deploy gradio-service \
  --source . \
  --region europe-west1 \
  --port 8080 \
  --allow-unauthenticated \
  --clear-base-image

# %%
# !gcloud run deploy gradio-service \
  --source /content/deploy_zone \
  --region europe-west1 \
  --port 8080 \
  --allow-unauthenticated

# %%
# !gcloud builds list --sort-by="~createTime" --limit 1 --format="value(id)" | xargs -I {} gcloud builds log {}

# %% [markdown]
# # OLD Section

# %%
# 1. Lokales Arbeitsverzeichnis in der VM erstellen
# !mkdir -p /content/sadtalker_deploy
# !cp -r /content/drive/MyDrive/SadTalker_Patched_2026/* /content/sadtalker_deploy/

# 2. In den lokalen VM-Ordner wechseln
# %cd /content/sadtalker_deploy

# 3. Sicherstellen, dass das Procfile dort liegt
# !echo "web: python app_sadtalker.py" > Procfile

# 4. Deployment aus der lokalen VM starten (nicht aus dem Drive!)
# !gcloud run deploy gradio-service \
  --source . \
  --region europe-west1 \
  --port 8080 \
  --allow-unauthenticated

# %%
# !gcloud builds submit --pack image=europe-west1-docker.pkg.dev/project-46810a95-b6e5-47e4-adb/cloud-run-source-deploy/gradio-test:latest .

# %%
# !ls -la /content/sadtalker_deploy

# %%
# !gcloud builds list --limit 3

# %%
# !gcloud builds log $(gcloud builds list --limit 1 --format="value(id)")

# %% [markdown]
# # JUNK Section

# %%
# !id -a
# !pwd

# %%
#%cd /content/gradio_app
#%cd /content
# %cd /content/drive/MyDrive/SadTalker_Patched_2026
# !pwd

# !echo "web: python app_sadtalker.py" > Procfile

#!gcloud run deploy gradio-service \
#  --source . \
#  --region europe-west1 \
#  --allow-unauthenticated

# !gcloud run deploy gradio-service \
  --source . \
  --region europe-west1 \
  --port 8080 \
  --allow-unauthenticated

# %% [markdown]
# # Domain Mapping Section

# %% [markdown]
# DNS NAME
#
# ---

# %%
# Replace 'your-domain.com' with your actual domain
# !gcloud beta run domain-mappings create \
  --service gradio-int \
  --domain us.kommunikator-gmbh.com \
  --region europe-west1

# %% [markdown]
# KORR DNS 1

# %%
# %cd /content/gradio_app
# !gcloud run deploy gradio-service \
  --source . \
  --region europe-west1 \
  --allow-unauthenticated

# %%
# !gcloud beta run domain-mappings create \
  --service gradio-service \
  --domain us.kommunikator-gmbh.com \
  --region europe-west1

# %%
# Replace 'your-domain.com' with your actual domain
# !gcloud beta run domain-mappings describe \
  --domain us.kommunikator-gmbh.com \
  --region europe-west1 \
  --format="yaml(status)"

# %% [markdown]
# # Add Password Section

# %% [markdown]
# ADD PW
#
#
# ---

# %%
# %cd /content

import os

# Update the main.py file with authentication
with open('gradio_app/main.py', 'w') as f:
    f.write("""
import gradio as gr
import os

def gruß_funktion(name):
    return f"Hallo {name}!"

demo = gr.Interface(fn=gruß_funktion, inputs="text", outputs="text")

if __name__ == "__main__":
    # Add authentication: (username, password)
    # You can also use a list for multiple users: [("admin", "pass123"), ("user", "user456")]
    demo.launch(
        server_name="0.0.0.0",
        server_port=8080,
        auth=("admin", "dein_geheimes_passwort")
    )
""")

# %%
# %cd /content/gradio_app
# !gcloud run deploy gradio-service \
  --source . \
  --region europe-west1 \
  --allow-unauthenticated

# %%
# 1. Enable the Secret Manager API
# !gcloud services enable ://googleapis.com

# 2. Create the secret container
# !gcloud secrets create GRADIO_PASSWORD --replication-policy="automatic"

# 3. Add the actual password to the secret
# Replace 'mein_geheimes_passwort' with your chosen password
# !echo -n "mein_geheimes_passwort" | gcloud secrets versions add GRADIO_PASSWORD --data-file=-

# %%
# Get your project number again
PROJECT_NUMBER = !gcloud projects describe {PROJECT_ID} --format='value(projectNumber)'
COMPUTE_SA = f"{PROJECT_NUMBER[0]}-compute@://gserviceaccount.com"

# Give the service account access to read secrets
# !gcloud projects add-iam-policy-binding {PROJECT_ID} \
    --member=serviceAccount:{COMPUTE_SA} \
    --role=roles/secretmanager.secretAccessor

# %%
# Fixed Service Account string
COMPUTE_SA = "1074528386995-compute@developer.gserviceaccount.com"
PROJECT_ID = "project-46810a95-b6e5-47e4-adb"

# Grant the Secret Manager accessor role
# !gcloud projects add-iam-policy-binding {PROJECT_ID} \
    --member=serviceAccount:{COMPUTE_SA} \
    --role=roles/secretmanager.secretAccessor

# %%
# %cd /content/gradio_app
# !gcloud run deploy gradio-service \
  --source . \
  --region europe-west1 \
  --set-secrets="MY_APP_PASSWORD=GRADIO_PASSWORD:latest" \
  --allow-unauthenticated

# %%
# 3. Add the actual password to the secret
# Replace 'mein_geheimes_passwort' with your chosen password
# !echo -n "mein_geheimes_passwort" | gcloud secrets versions add GRADIO_PASSWORD --data-file=-

# %%
# %cd /content

with open('gradio_app/main.py', 'w') as f:
    f.write("""
import gradio as gr
import os

# Function to get secret from environment (injected by Cloud Run)
def get_password():
    return os.environ.get("MY_APP_PASSWORD", "default_fallback_pass")

def gruß_funktion(name):
    return f"Hallo {name}!"

demo = gr.Interface(fn=gruß_funktion, inputs="text", outputs="text")

if __name__ == "__main__":
    demo.launch(
        server_name="0.0.0.0",
        server_port=8080,
        auth=("admin", get_password())
    )
""")

# %%
# %cd /content/gradio_app
# !gcloud run deploy gradio-service \
  --source . \
  --region europe-west1 \
  --set-secrets="MY_APP_PASSWORD=GRADIO_PASSWORD:latest" \
  --allow-unauthenticated

# %% [markdown]
# # DNS  SSL STATUS Section

# %%
# Replace with your actual domain
# !host gradio-service.us.kommunikator-gmbh.com

# %%
# !gcloud beta run domain-mappings describe \
  --domain int.us.kommunikator-gmbh.com \
  --region europe-west1 \
  --format="yaml(status)"
